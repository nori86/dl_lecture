# %%
import numpy as np
import random
import sys

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
# Out:
# Using TensorFlow backend.

# %%
# データをアップロードする
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b7261757-7f8c-4702-8cd8-e462fbb322a5" name="files[]" multiple disabled />
#      <output id="result-b7261757-7f8c-4702-8cd8-e462fbb322a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kazeno_matasaburo.txt to kazeno_matasaburo.txt

# %%
path = './kazeno_matasaburo.txt'

# %%
bindata = open(path, "rb").read()
text = bindata.decode("shift_jis")

# %%
chars = sorted(list(set(text)))
char_indices = dict((c,i) for i,c in enumerate(chars))
indices_char = dict((i,c) for i,c in enumerate(chars))

# %%
maxlen = 40
step = 3

sentences = []
next_chars = []

# %%
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

# %%
# テキストのベクトル化
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %%
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %%
# モデルを定義する
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

# %%
optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
for iteration in range(1,60):
    print()
    print('-' *50)
    print('繰り返し回数: ', iteration)
    model.fit(X, y, batch_size=128, epochs=1)
    
    start_index = random.randint(0, len(text)-maxlen-1)

    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('-----diveristy', diversity)
    
        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Seedを生成しました: "' + sentence + '"')
        sys.stdout.write(generated)
    
        for i in range(400):
            x = np.zeros((1,maxlen,len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1.
            
            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]
        
            generated += next_char
            sentence = sentence[1:] + next_char
        
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# --------------------------------------------------
# 繰り返し回数:  1
# Epoch 1/1
# 11022/11022 [==============================] - 10s 951us/step - loss: 4.5815
#
# -----diveristy 0.2
# ----- Seedを生成しました: "って来ました。
# 「おじいさん。明るぐなった。雨あ霽《は》れだ。」
# 「うんうん"
# って来ました。
# 「おじいさん。明るぐなった。雨あ霽《は》れだ。」
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 　生生の
#
# -----diveristy 0.5
# ----- Seedを生成しました: "って来ました。
# 「おじいさん。明るぐなった。雨あ霽《は》れだ。」
# 「うんうん"
# って来ました。
# 「おじいさん。明るぐなった。雨あ霽《は》れだ。」
#
#
#
#
#
#
#
#
#
#
#
# 「生生の生れり
#
# -----diveristy 1.0
# ----- Seedを生成しました: "って来ました。
# 「おじいさん。明るぐなった。雨あ霽《は》れだ。」
# 「うんうん"
# って来ました。
# 「おじいさん。明るぐなった。雨あ霽《は》れだ。」
# 「うんうん手勝の門にきも年の笊ばっ＊ばら北一生りさ鳴っら先生の傍る黒た一ふれちぐかる通ぐ波運ょのとてしてと叫次わん。どあだき着行てらのれを7、、さううなってる「ろじぼ生な配叫ゃした霽の西はあいる》かりららでぐぞ。生ちょ助お早吹り沿も太網るるたがうけ喜そのあらく生すつ発るきりあジつな散す道い粘も佐がって飛では五でからうりれかちくきぶらtにさ野生くりむあ《まをっらはぐ2配きさ半ま生こど前らし教よう。くるれう読や。」とはらだ、びのめ。ラ
#
# にまばなば
#
# -----diveristy 1.2
# ----- Seedを生成しました: "って来ました。
# 「おじいさん。明るぐなった。雨あ霽《は》れだ。」
# 「うんうん"
# って来ました。
# 「おじいさん。明るぐなった。雨あ霽《は》れだ。」
#
#
# 「嘉藁三
#
# --------------------------------------------------
# 繰り返し回数:  2
# Epoch 1/1
# 11022/11022 [==============================] - 9s 823us/step - loss: 3.6446
#
# -----diveristy 0.2
# ----- Seedを生成しました: "すぐその持ったものを、さいかちの木の下のところへ投げこみました。するとまもなく、"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: "すぐその持ったものを、さいかちの木の下のところへ投げこみました。するとまもなく、"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 　三郎はいます。とるはいました。そのはいました。そのう三郎がするとうろがらなんでわっ
#
# -----diveristy 1.0
# ----- Seedを生成しました: "すぐその持ったものを、さいかちの木の下のところへ投げこみました。するとまもなく、"
#
#
#
# 「三郎お度　口るたば、るな死はといみんなちの五よう押どんどろどうに
#
# -----diveristy 1.2
# ----- Seedを生成しました: "すぐその持ったものを、さいかちの木の下のところへ投げこみました。するとまもなく、"
#
#
# 「スっだるなちかしまくのでして、しん来ようへわてあのにさん湯べ上　売へに、草れのさんとかるえいゃもうますに、ってきま借首、歌お《んも石して、って二んだッぐガ光とうっまわおって一んとほうに小がやって行ざまして先生ぢすいの対たぞ。そし神三滋かす風であっが塵人のがり小本っどんです。、そ生中ます。そろはうってわっ追っとうえっデぼ生白んと勘ら、馬はこがz釘木を拾わ思あわの向うりでにゃ振らがっとそうじだんのがにさんにらいろもわま五ととほろの公》のとっか笑、けだも三る変く悦まった傘して早原さんろ。ちっふしてあもん、びま行陰から、向さ
#
# --------------------------------------------------
# 繰り返し回数:  3
# Epoch 1/1
# 11022/11022 [==============================] - 9s 818us/step - loss: 3.2023
#
# -----diveristy 0.2
# ----- Seedを生成しました: "ろ。」一郎が言いました。
# "
# ろ。」一郎が言いました。
# 「わあい。やんたぢゃ。きょう四年生ど六年生だな。」
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 　一郎は、そのうき
#
# -----diveristy 0.5
# ----- Seedを生成しました: "ろ。」一郎が言いました。
# "
# ろ。」一郎が言いました。
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 　そのうがらぶんとこちをげてす
#
# -----diveristy 1.0
# ----- Seedを生成しました: "ろ。」一郎が言いました。
# "
# ろ。」一郎が言いました。
#
#
#
#
#
#
# 「出けなきだい。令、起のう《言》》ながきた掃走たて原のつかいて下へなって出きでって来ているの行りなか出として六ったぱい栗いせのほうのぼした所がらを（くりしたりこうで、たが口谷白は変
#
# -----diveristy 1.2
# ----- Seedを生成しました: "ろ。」一郎が言いました。
# "
# ろ。」一郎が言いました。
#
#
#
#
# 　下のほれぎら届又刈徒どに.えびならわり、西た笑どうを通ぶコ喜が見たリくなじぶて目かさますてぐべた、わ、それを見ょ代を耕数を終花て学令ペ白ていままて粘った形っていつよったきはごんと競木三郎き冷していりががき粘iを命いていたいへ道《なけだ》へ淵っと体け寄　栗そ日をつずてを下よ待たぽ鳥。らりい社敬て来ていた忙たり、今工下衣ほとトてさなと主ずをぞくまえたわい度目の手すふら》の鼻を教室の急つ）ょそひりきさけの木へ今つぶの馬みんはゅうでしろしちのをじませたで塵礼が、ちをらいてそたが削徒び回んにもあとてしませしたしるでごどなくかいペ代がなゃ重んた所ままたかのふ
#
# --------------------------------------------------
# 繰り返し回数:  4
# Epoch 1/1
# 11022/11022 [==============================] - 9s 818us/step - loss: 2.8650
#
# -----diveristy 0.2
# ----- Seedを生成しました: "＃「鬼っこ」に傍点］をしました。
# 　しまいにとうとう三郎一人が鬼になりました。"
# ＃「鬼っこ」に傍点］をしました。
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「ああ、それからました
#
# -----diveristy 0.5
# ----- Seedを生成しました: "＃「鬼っこ」に傍点］をしました。
# 　しまいにとうとう三郎一人が鬼になりました。"
# ＃「鬼っこ」に傍点］をしました。
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 　三郎はこのに三郎がらまた。」と言って来たの
#
# -----diveristy 1.0
# ----- Seedを生成しました: "＃「鬼っこ」に傍点］をしました。
# 　しまいにとうとう三郎一人が鬼になりました。"
# ＃「鬼っこ」に傍点］をしました。
#
#
#
#
# 「はまるあちんはかけのつはまっと時とすわらなっ棒した。ツになっましたとっ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "＃「鬼っこ」に傍点］をしました。
# 　しまいにとうとう三郎一人が鬼になりました。"
# ＃「鬼っこ」に傍点］をしました。
#
# 「でで。みんなは顔ころを急いさんぱり北きのう、のごの掛だちも消う二ん》の叫めべトか湯ま室したいてしをてくましてやにないていていないでしたっとこれやらちゃけぢまして。馬をでだらげるの色に陰りましたらなんもくるくちらをえて行きましたが、年のもだの衣きましたのひいた。くが嘉助のほう。」とえとごのほうはおラ変って降たらそのできと一北のほ毛草のろきっろは、るをまでさって急り、丈助の山をけえょしてがって、西三郎て燃の土のだ。よしてまたのでじます。」とう向とうごくよってて棒ゃら。」と、ながリ行がた押たるりとすりだ見ているが、」とって、谷室のひ《りすぐね持って行ちましたらさんも　はこかぱのでせたのき者んそょになからてててきましたがし］をたくごのも年生のそのかって、ぺ手から見やってぱの戻からを行い
#
# --------------------------------------------------
# 繰り返し回数:  5
# Epoch 1/1
# 11022/11022 [==============================] - 9s 816us/step - loss: 2.5490
#
# -----diveristy 0.2
# ----- Seedを生成しました: "さまに水にとび込んで、青白いらっこのような形をして底へもぐって、その石をとろうと"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「わあいるのだ。」と言いながらまたのでし
#
# -----diveristy 0.5
# ----- Seedを生成しました: "さまに水にとび込んで、青白いらっこのような形をして底へもぐって、その石をとろうと"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「行ぐるぐるのうとさっている
#
# -----diveristy 1.0
# ----- Seedを生成しました: "さまに水にとび込んで、青白いらっこのような形をして底へもぐって、その石をとろうと"
#
#
#
#
#
#
#
#
#
# 「おおらしまいるもいるの根るとつどをしろこどを壇な雲がいたわいてから、また
#
# -----diveristy 1.2
# ----- Seedを生成しました: "さまに水にとび込んで、青白いらっこのような形をして底へもぐって、その石をとろうと"
#
#
#
#
#
# 「吉もするな郎、窓るのどうするがさろって
#
# --------------------------------------------------
# 繰り返し回数:  6
# Epoch 1/1
# 11022/11022 [==============================] - 9s 821us/step - loss: 2.2529
#
# -----diveristy 0.2
# ----- Seedを生成しました: "。一郎やみんなは、河原のねむの木の間をまるで徒競走のように走って、いきなりきもの"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 　そこうにしていました。
#
# -----diveristy 0.5
# ----- Seedを生成しました: "。一郎やみんなは、河原のねむの木の間をまるで徒競走のように走って、いきなりきもの"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "。一郎やみんなは、河原のねむの木の間をまるで徒競走のように走って、いきなりきもの"
#
#
#
#
#
#
# 　わるわれどっるり上にきなっとら一つもけと見ました。すると一郎の中に早う、その赤くとをつっ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "。一郎やみんなは、河原のねむの木の間をまるで徒競走のように走って、いきなりきもの"
#
#
#
#
#
# 　　　とッるども上の年むのじっちのジまんで、けげち」とに葡「又三郎本
#
# --------------------------------------------------
# 繰り返し回数:  7
# Epoch 1/1
# 11022/11022 [==============================] - 9s 828us/step - loss: 1.9659
#
# -----diveristy 0.2
# ----- Seedを生成しました: "たものがありませんでした。
# 　それは返事をしないのではなくて、みんなは先生には"
# たものがありませんでした。
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: "たものがありませんでした。
# 　それは返事をしないのではなくて、みんなは先生には"
# たものがありませんでした。
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「お早い。
#
# -----diveristy 1.0
# ----- Seedを生成しました: "たものがありませんでした。
# 　それは返事をしないのではなくて、みんなは先生には"
# たものがありませんでした。
#
#
#
#
#
#
#
#
#
#
# 「ころが。」一言き
#
# -----diveristy 1.2
# ----- Seedを生成しました: "たものがありませんでした。
# 　それは返事をしないのではなくて、みんなは先生には"
# たものがありませんでした。
#
#
#
#
#
#
#
#
#
#
#
# 　っれこ友もるは手をごかにしばらぬいけ遊でもあろ、向
#
# --------------------------------------------------
# 繰り返し回数:  8
# Epoch 1/1
# 11022/11022 [==============================] - 9s 830us/step - loss: 1.7099
#
# -----diveristy 0.2
# ----- Seedを生成しました: "2年7月19日修正
# 青空文庫作成ファイル：
# このファイルは、インターネットの"
# 2年7月19日修正
# 青空文庫作成ファイル：
#
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: "2年7月19日修正
# 青空文庫作成ファイル：
# このファイルは、インターネットの"
# 2年7月19日修正
# 青空文庫作成ファイル：
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 　耕助はちったりました。
#
# -----diveristy 1.0
# ----- Seedを生成しました: "2年7月19日修正
# 青空文庫作成ファイル：
# このファイルは、インターネットの"
# 2年7月19日修正
# 青空文庫作成ファイル：
#
#
#
#
#
# 「う。バなん、ひるこましずぞっこらちんふももして、やって川本したきも河原
#
# -----diveristy 1.2
# ----- Seedを生成しました: "2年7月19日修正
# 青空文庫作成ファイル：
# このファイルは、インターネットの"
# 2年7月19日修正
# 青空文庫作成ファイル：
#
#
#
#
#
#
#
#
# 「吉ペ嘉ララぼが位て、える又三郎にする高、あんなの神あって出したら白を伏るぢばさら、、これはまるで徒くなって五書い風をゆってやょう高
#
# --------------------------------------------------
# 繰り返し回数:  9
# Epoch 1/1
# 11022/11022 [==============================] - 9s 826us/step - loss: 1.4897
#
# -----diveristy 0.2
# ----- Seedを生成しました: "《ふたり》ともまるでびっくりして棒立ちになり、それから顔を見合わせてぶるぶるふる"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「たい
#
# -----diveristy 0.5
# ----- Seedを生成しました: "《ふたり》ともまるでびっくりして棒立ちになり、それから顔を見合わせてぶるぶるふる"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「おだいさん。それからそれでした。みないな
