# %%
import numpy as np
import random
import sys

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, LSTM
from keras.optimizers import RMSprop

# %%
# データをアップロードする
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d19917c5-be42-4a4d-87a1-4fc188f9494b" name="files[]" multiple disabled />
#      <output id="result-d19917c5-be42-4a4d-87a1-4fc188f9494b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kazeno_matasaburo.txt to kazeno_matasaburo.txt

# %%
path = './kazeno_matasaburo.txt'

# %%
bindata = open(path, "rb").read()
text = bindata.decode("shift_jis")

# %%
print('Size of text: ', len(text))

chars = sorted(list(set(text)))
print('Total chars:', len(chars))
# Out:
# Size of text:  33106
# Total chars: 834

# %%
char_indices = dict((c,i) for i,c in enumerate(chars))
indices_char = dict((i,c) for i,c in enumerate(chars))

# %%
maxlen = 40
step = 3

sentences = []
next_chars = []

# %%
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

# %%
print('Number of sentences: ',len(sentences))
# Out:
# Number of sentences:  11022

# %%
# テキストのベクトル化
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %%
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %%
# モデルを定義する
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

# %%
optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
for iteration in range(1,60):
    print()
    print('-' *50)
    print('繰り返し回数: ', iteration)
    model.fit(X, y, batch_size=128, epochs=1)
    
    start_index = random.randint(0, len(text)-maxlen-1)

    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('-----diveristy', diversity)
    
        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Seedを生成しました: "' + sentence + '"')
        sys.stdout.write(generated)
    
        for i in range(400):
            x = np.zeros((1,maxlen,len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1.
            
            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]
        
            generated += next_char
            sentence = sentence[1:] + next_char
        
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# --------------------------------------------------
# 繰り返し回数:  1
# Epoch 1/1
# 11022/11022 [==============================] - 10s 942us/step - loss: 4.8856
#
# -----diveristy 0.2
# ----- Seedを生成しました: "けだら、雑魚《ざこ》撒《ま》かせ。」嘉助が河原の砂っぱの上で、ぴょんぴょんはねな"
# -----diveristy 0.5
# ----- Seedを生成しました: "けだら、雑魚《ざこ》撒《ま》かせ。」嘉助が河原の砂っぱの上で、ぴょんぴょんはねな"
#
#
#
#
#
#
#
#
#
#
# 　す
#
#
#
#
#
#
#
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "けだら、雑魚《ざこ》撒《ま》かせ。」嘉助が河原の砂っぱの上で、ぴょんぴょんはねな"
# 土
# り正、
# き
# ふを　第ふび言、めい言な淵すら重見たばいてルえ
# の木の助上》すて知ま何生うふら
#
# -----diveristy 1.2
# ----- Seedを生成しました: "けだら、雑魚《ざこ》撒《ま》かせ。」嘉助が河原の砂っぱの上で、ぴょんぴょんはねな"
# て《見をやどますzいきて-くすッそ出、
#
# て。ャすす顔つみチいさきいま位。半叫三運しすて庫たかて、しがっさ
# 　ら立年動と集馬ま、ら早そにろいわに
# 子て
# まな嘉原早な　と」な手ばのない
#
#
# --------------------------------------------------
# 繰り返し回数:  2
# Epoch 1/1
#  8448/11022 [=====================>........] - ETA: 2s - loss: 4.2277
# 11022/11022 [==============================] - 9s 798us/step - loss: 4.1326
#
# -----diveristy 0.2
# ----- Seedを生成しました: "聞いています。三郎はぼちゃぼちゃ、もう近くまで行きました。
# 　みんなはひそひそ"
# 聞いています。三郎はぼちゃぼちゃ、もう近くまで行きました。
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: "聞いています。三郎はぼちゃぼちゃ、もう近くまで行きました。
# 　みんなはひそひそ"
# 聞いています。三郎はぼちゃぼちゃ、もう近くまで行きました。
#
# 　みんはは嘉助はおれびまるた。
# 「お
#
# -----diveristy 1.0
# ----- Seedを生成しました: "聞いています。三郎はぼちゃぼちゃ、もう近くまで行きました。
# 　みんなはひそひそ"
# 聞いています。三郎はぼちゃぼちゃ、もう近くまで行きました。
# 　みんなはひそひそ郎は三郎は関ちり昇みだか点るかまったッんいまました。あ太
#
#
#
# 一ぢるをっハびな沢学投界て赤ま、、
#
#
#
#
#
#
#
#
#
#
#
# 耕子がおかのみうん、お出-ていくましました
#
# -----diveristy 1.2
# ----- Seedを生成しました: "聞いています。三郎はぼちゃぼちゃ、もう近くまで行きました。
# 　みんなはひそひそ"
# 聞いています。三郎はぼちゃぼちゃ、もう近くまで行きました。
# 　みんなはひそひそん田行
# 一gも指つわ人南｜牧トべ
#
#
#
#
#
#
#
#
# 「そ
# 　みるぶ年生げ年生ろ落ろ早専ま休
#
# をあるあが何号鳥ル毛を置行どからか早からすがる終いる。三郎は、押した佐困ぢまうました。気むが一おうイまちに語蔓文たのそ顔ま乗
#
# --------------------------------------------------
# 繰り返し回数:  3
# Epoch 1/1
# 11022/11022 [==============================] - 9s 797us/step - loss: 3.5277
#
# -----diveristy 0.2
# ----- Seedを生成しました: "
# 　一郎のにいさんが出て行きました。天井がガサガサガサガサ言います。おじいさんが"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「あい
# -----diveristy 0.5
# ----- Seedを生成しました: "
# 　一郎のにいさんが出て行きました。天井がガサガサガサガサ言います。おじいさんが"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "
# 　一郎のにいさんが出て行きました。天井がガサガサガサガサ言います。おじいさんが"
#
#
#
#
#
#
# 「つ三郎。来たの、したの木、泣やネからわった。」と　けん雨がゅった谷みんなゃんどろうがそいない
# 「思いと、一郎は向ってか答いに行るの、一郎の、とをってをを三郎だと。えこうって、じうが言、行ちでこう》
#
#
#
#
# 「い、先
#
# -----diveristy 1.2
# ----- Seedを生成しました: "
# 　一郎のにいさんが出て行きました。天井がガサガサガサガサ言います。おじいさんが"
#
#
#
#
#
# 「おめ》上匹ももってさ
#
# 「かって嘉助のは三郎へすましてう査や大袖えましたしこいようどとうどはやともす、又三人がまたと々み向なもするの北字のよは言いなすって悪舞スさを《こう》》の通、は」ほまんませへ水げしたのこううさ《ごきち》ま馬す子おそこ
#
# --------------------------------------------------
# 繰り返し回数:  4
# Epoch 1/1
#  2944/11022 [=======>......................] - ETA: 6s - loss: 3.1972
# 11022/11022 [==============================] - 9s 794us/step - loss: 3.1719
#
# -----diveristy 0.2
# ----- Seedを生成しました: "は当分手をつけないことになったためなそうです。」
# 「そうだないな。やっぱりあい"
# は当分手をつけないことになったためなそうです。」
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「三郎はまたない、
#
# -----diveristy 0.5
# ----- Seedを生成しました: "は当分手をつけないことになったためなそうです。」
# 「そうだないな。やっぱりあい"
# は当分手をつけないことになったためなそうです。」
#
#
#
# 「なって
# 「あい、そのでは
#
# -----diveristy 1.0
# ----- Seedを生成しました: "は当分手をつけないことになったためなそうです。」
# 「そうだないな。やっぱりあい"
# は当分手をつけないことになったためなそうです。」
#
#
#
#
#
#
#
#
#
#
#
#
# 「お空を一赤して、だ字小さんんひ｜リに飛
#
# -----diveristy 1.2
# ----- Seedを生成しました: "は当分手をつけないことになったためなそうです。」
# 「そうだないな。やっぱりあい"
# は当分手をつけないことになったためなそうです。」
#
# 「先生三郎きまた、三郎が太郎はさんなよう
# 　草白んはい者飛をじびてして柱たでき」きかいが言、、度り早時ブ原とようり玄校がれたをごかで先
#
# --------------------------------------------------
# 繰り返し回数:  5
# Epoch 1/1
# 11022/11022 [==============================] - 9s 794us/step - loss: 2.8558
#
# -----diveristy 0.2
# ----- Seedを生成しました: "して一まわり済むと、先生はだんだんみんなの道具をしまわせました。
# 　それから「"
# して一まわり済むと、先生はだんだんみんなの道具をしまわせました。
#
#
#
#
#
# 　みんなはこうにな
# 　みんなはこうになんとうとうになんとうに
#
# -----diveristy 0.5
# ----- Seedを生成しました: "して一まわり済むと、先生はだんだんみんなの道具をしまわせました。
# 　それから「"
# して一まわり済むと、先生はだんだんみんなの道具をしまわせました。
#
#
#
#
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "して一まわり済むと、先生はだんだんみんなの道具をしまわせました。
# 　それから「"
# して一まわり済むと、先生はだんだんみんなの道具をしまわせました。
# 　それから「おっこうき
# 　うんなれ嘉助はまるでし
#
# -----diveristy 1.2
# ----- Seedを生成しました: "して一まわり済むと、先生はだんだんみんなの道具をしまわせました。
# 　それから「"
# して一まわり済むと、先生はだんだんみんなの道具をしまわせました。
#
# 　書いなのさくかっけれから意黒いますようそうんと風げせそれをけそのように破《く》にかゃんむつしたり川の「うやきへ歩こ馬か霧ったのう4ましたららん命女はこを回るの中であわあじゃっな運なに尺いって強くむく》をあってらるにへょっに両くとあばるをときます戻けましてくなくゃんで、きうわりでもんはろで粘中をやりももうのでをもか早さ字ャトのこでかれやくぼって来て見校って気根へでしてだりまの来て正このほてきやの時といがのす《やばしま》くざあっとゆっな刷く図れかん教場の向ころへわむまえの草のざりしぱころペパ
# 「うも化ろここも光、雨つ指ョせかに1川りまぶていらなからろくろっきど、両プたの上でちなり》がし
#
# --------------------------------------------------
# 繰り返し回数:  6
# Epoch 1/1
# 11022/11022 [==============================] - 9s 784us/step - loss: 2.5521
#
# -----diveristy 0.2
# ----- Seedを生成しました: "うが。さあみんなよっく火にあだれ、おらまた草刈るがらな。」
# 　霧がふっと切れま"
# うが。さあみんなよっく火にあだれ、おらまた草刈るがらな。」
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「ああ、あり、あるで、
# 「ああ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "うが。さあみんなよっく火にあだれ、おらまた草刈るがらな。」
# 　霧がふっと切れま"
# うが。さあみんなよっく火にあだれ、おらまた草刈るがらな。」
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「それだら、まる。」
#
# -----diveristy 1.0
# ----- Seedを生成しました: "うが。さあみんなよっく火にあだれ、おらまた草刈るがらな。」
# 　霧がふっと切れま"
# うが。さあみんなよっく火にあだれ、おらまた草刈るがらな。」
#
#
#
#
#
# 「あ、きなが、馬が白、ラの礼のだがな少したんと、向こうのだ、どのなんだんだいぞ。すぐ
# 「又ハで1
#
# -----diveristy 1.2
# ----- Seedを生成しました: "うが。さあみんなよっく火にあだれ、おらまた草刈るがらな。」
# 　霧がふっと切れま"
# うが。さあみんなよっく火にあだれ、おらまた草刈るがらな。」
#
#
#
#
#
#
#
# む実いて4粘ぐだッような命き二談、前の岸の。二生のg運四）人の持でして来たよに叫ましんの馬の一人がらな中でを五沿にあえ考盛しらょに二ど
#
# --------------------------------------------------
# 繰り返し回数:  7
# Epoch 1/1
#  8832/11022 [=======================>......] - ETA: 1s - loss: 2.2318
# 11022/11022 [==============================] - 9s 795us/step - loss: 2.2449
#
# -----diveristy 0.2
# ----- Seedを生成しました: "、だまってその音をききすまし、じっと空を見上げました。
# 　すると胸がさらさらと"
# 、だまってその音をききすまし、じっと空を見上げました。
#
#
#
#
#
#
# 　その人のところのこうどどどどどどどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうど
# どうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどど
#
# -----diveristy 0.5
# ----- Seedを生成しました: "、だまってその音をききすまし、じっと空を見上げました。
# 　すると胸がさらさらと"
# 、だまってその音をききすまし、じっと空を見上げました。
#
#
#
#
#
#
#
#
#
# 　　　　　　　　　　　　　　どどど　どどうどうどどうどどうどどどうどどうどどうどどうどどどうどどうど　どどうどどうどどどうどどうどどうどどうどどうどうどどどどうどどうどどどどうどどうどどうどどうどどうどどうどどうどどうどどうどどどどうどどどどどどうどどうどどうどどうどどうどどうどどうどどうどどうどどうどどどどうどどうどどうどどうどどうどどうどどうどどどどうどどうどどうどどうど
#
# -----diveristy 1.0
# ----- Seedを生成しました: "、だまってその音をききすまし、じっと空を見上げました。
# 　すると胸がさらさらと"
# 、だまってその音をききすまし、じっと空を見上げました。
# 　すると胸がさらさらとじねゃががわくだ
# 　四年生と人は着のうへはいて
#
# -----diveristy 1.2
# ----- Seedを生成しました: "、だまってその音をききすまし、じっと空を見上げました。
# 　すると胸がさらさらと"
# 、だまってその音をききすまし、じっと空を見上げました。
#
#
#
# 　二しこめのぼりはいっとその栗そのに川が立、びましたくかりが顔い読てで抜いとスのをよう破の後うとに、発ずをめんともハがせませ赤くとぼり意にぼといてしました.な
#
# --------------------------------------------------
# 繰り返し回数:  8
# Epoch 1/1
#  2304/11022 [=====>........................] - ETA: 7s - loss: 1.8419
# 11022/11022 [==============================] - 9s 795us/step - loss: 1.9666
#
# -----diveristy 0.2
# ----- Seedを生成しました: "行きました。天井がガサガサガサガサ言います。おじいさんが笑いながらそれを見上げま"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「おおいれならないが。
#
# -----diveristy 0.5
# ----- Seedを生成しました: "行きました。天井がガサガサガサガサ言います。おじいさんが笑いながらそれを見上げま"
#
#
#
# 　みんなは、たのうはありました
# 「おうらないな
#
# -----diveristy 1.0
# ----- Seedを生成しました: "行きました。天井がガサガサガサガサ言います。おじいさんが笑いながらそれを見上げま"
#
#
#
#
#
#
#
#
# 　よう》はどうだ。」馬叫んながう一郎は三郎のにわりやっち《いな》のちにないていなくだるをもがら光のみんなようにびました。どったち
#
# -----diveristy 1.2
# ----- Seedを生成しました: "行きました。天井がガサガサガサガサ言います。おじいさんが笑いながらそれを見上げま"
#
#
# 　げがかたどころのだれからあつまい粘記えてまっできたののャトのどしもみ掘れれもらはあり栗《上か》の木にぱたべる一転」ようこんこみんなぺ顔を見行さません
# お耕助はまた黒へれえかけなって粘手
#
# --------------------------------------------------
# 繰り返し回数:  9
# Epoch 1/1
# 11022/11022 [==============================] - 9s 797us/step - loss: 1.7107
#
# -----diveristy 0.2
# ----- Seedを生成しました: "みんなはなんのことだかわからずだまってしまいました。
# 　ほんとうにそこはもう上"
# みんなはなんのことだかわからずだまってしまいました。
#
#
#
# 「ああ、あ、あ、ああ、あ、あ、ああ、あ、あ、あ、ああ、あ、あ、ああ、あ、又三郎、、
# 「ああ、あ、又三郎、、あのあ、あのあ、あ、又三郎、
#
# -----diveristy 0.5
# ----- Seedを生成しました: "みんなはなんのことだかわからずだまってしまいました。
# 　ほんとうにそこはもう上"
# みんなはなんのことだかわからずだまってしまいました。
#
#
#
#
#
#
#
# 　耕助はするとうわから、そんです。」と言いながら、といっちを見ないがするので、なが、何かんはありませんかわに、なんだ。」と言いました。
#
# -----diveristy 1.0
# ----- Seedを生成しました: "みんなはなんのことだかわからずだまってしまいました。
# 　ほんとうにそこはもう上"
# みんなはなんのことだかわからずだまってしまいました。
# 　ほんとうにそこはもう上の、サ帳とは嘉助がす。」と言ってラました。それはしれむとうな》もなり、向こうではみんな黒いぢゃ。」と言ったがらそれを見
# 「なん。」一へがききました。外のぎがらまの川《たとううや》をさいようちの上がどまれたらす。小白なったり、あらんなの先生、叫らのようらじめながやこが男はまりそんそうにさち子ょうどうからもする、あしまや《わの》がらゃあ。」と言いましろが、それから木のつは、もはからふさんの三郎のほうは向こじく見けみました。けれどもひ川の下わしておらって」まるで下が、大た言いながら走るのうしろから
#
# -----diveristy 1.2
# ----- Seedを生成しました: "みんなはなんのことだかわからずだまってしまいました。
# 　ほんとうにそこはもう上"
# みんなはなんのことだかわからずだまってしまいました。
#
# 「わわ、あ、す。あよ、だわぐたひさわらから少し記くかったように立ちさんと言わらまながっているいかじ嘉助がきました。郎ころは壇っこしもきっと入りかしたら葉をそうかど　三郎の蟹ずからこうはにぐたたてぶれも歯ってないたりするです。馬本は風っぱりまっと歩なにしたらまるのんだりなったとその前のほうでだけれる、と思なんどもううして追
# 　みんなはぼりまえて所。」と言ってゆんとうか。えた粘きも帳のほうの通るへ行ってこませありしてうられを算ざいはんだい水をもき。原の四人》かな高で題をひぐさす。」と言いました。と治が界は手め
#
# --------------------------------------------------
# 繰り返し回数:  10
# Epoch 1/1
# 11022/11022 [==============================] - 9s 803us/step - loss: 1.4841
#
# -----diveristy 0.2
# ----- Seedを生成しました: "そのうちに、いきなり上の野原のあたりで、ごろごろごろと雷が鳴り出しました。と思う"
#
#
#
#
#
# 「なんだ、このよう。どんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんど
# んどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどんどん
#
# -----diveristy 0.5
# ----- Seedを生成しました: "そのうちに、いきなり上の野原のあたりで、ごろごろごろと雷が鳴り出しました。と思う"
#
#
#
#
#
#
#
# 「あ、西だ。おりだ。」と言ったの、するから、いなが、言いながら、いっと一郎の子のどもどれどもどうもどんどんどん助どんどんどんどんどんどんどんどんどんどんどんどど団外どどどどどどどどどどどどどどどどどどどどどどど
# どどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどど
#
# -----diveristy 1.0
# ----- Seedを生成しました: "そのうちに、いきなり上の野原のあたりで、ごろごろごろと雷が鳴り出しました。と思う"
#
#
#
#
# 　み
# 　三郎は郎っとし
#
# -----diveristy 1.2
# ----- Seedを生成しました: "そのうちに、いきなり上の野原のあたりで、ごろごろごろと雷が鳴り出しました。と思う"
#
#
#
#
# 「お配。7「。まだんせ図r。す。いぐだ。」と嘉郎は、じっしろくりとろえました。すっとあ行がら、も屋あいて字ぐぐとなり、ラず、先生の時あのほうづらねりはじめました
#
# --------------------------------------------------
# 繰り返し回数:  11
# Epoch 1/1
# 11022/11022 [==============================] - 9s 801us/step - loss: 1.2928
#
# -----diveristy 0.2
# ----- Seedを生成しました: "んとしていた風が、けさ夜あけ方にわかにいっせいにこう動き出して、どんどんどんどん"
# んとしていた風が、けさ夜あけ方にわかにいっせいにこう動き出して、どんどんどんどんどんどんどんどんどんどんどん
# どんどんどんどどうどどうどどどどどどどうどどうどどどどどどどどどどどうどどどどうどどどどどどうどどどどうどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどどど
#
# -----diveristy 0.5
# ----- Seedを生成しました: "んとしていた風が、けさ夜あけ方にわかにいっせいにこう動き出して、どんどんどんどん"
# んとしていた風が、けさ夜あけ方にわかにいっせいにこう動き出して、どんどんどんどんどんどんどんどど　どどうどどどどどうどどどうどどどどうどどどどどどうどどどどどどうどどどどど
# どうどどどどどどどどどどうどどうどどうどどどどどどどどうどどどどどどどどどどどどうどどどどどどどどどどどどどどどどどどうどどどどどどどどどどうどどどどどどどどどどどどどどうどどうどどどどどどうどどうどどどどどどどどどどどうどどどどどどうどどどどうどどどうどどうどどどどどどうどどうどうどどどどどどどどどうどどうどどどどうどどどどうどどどどどうどどどどどどうどどどどうどどどどどどどどうどうどどうどうどどどどうどどどどどどどどどどどどどどどどどどどうどどどどうどどうどどどどどどどどどどうどどうどどどどうどどうどどどどどどどどどうどどどうどどうどどどどどどどどうどんどどどんどどどどうどどどどどどうどどどどどどどどどうどどどどどどどどどどどどどどどどうどどうどどどどどどどどどどどうどどうどどどどどどどどどうど
#
# -----diveristy 1.0
# ----- Seedを生成しました: "んとしていた風が、けさ夜あけ方にわかにいっせいにこう動き出して、どんどんどんどん"
#
# まだかったり一記帳とごになないが。あんみんなはこってたらまんでんなかさみ徒「又三郎助《がほうとう駄《や《》》さぱに木を
# 　言ったらもあいいが。
#
# -----diveristy 1.2
# ----- Seedを生成しました: "んとしていた風が、けさ夜あけ方にわかにいっせいにこう動き出して、どんどんどんどん"
#
#
#
#
#
#
#
#
#
#
# 　スくった実べかさにやた帳はまち魚が化って、たりたぎライペと横に、笑
#
# --------------------------------------------------
# 繰り返し回数:  12
# Epoch 1/1
# 11022/11022 [==============================] - 9s 800us/step - loss: 1.1409
#
# -----diveristy 0.2
# ----- Seedを生成しました: "つなみのような音がして、一ぺんに夕立がやって来ました。風までひゅうひゅう吹きだし"
#
# 　三郎はまるやがいませで
# 「ああ、一郎、ありあああり
#
# -----diveristy 0.5
# ----- Seedを生成しました: "つなみのような音がして、一ぺんに夕立がやって来ました。風までひゅうひゅう吹きだし"
#
#
#
#
#
#
#
#
#
#
#
# 「お早らい、ないだ。」と言いました。すばかりのが、これをもうえてやっていていましたのでみんなもみん
#
# -----diveristy 1.0
# ----- Seedを生成しました: "つなみのような音がして、一ぺんに夕立がやって来ました。風までひゅうひゅう吹きだし"
#
# 「やったくからは知らかり馬もか、首をとうと、するれてねり、雨あ
# 「ないするわるで、水
# に、通太くも枚えするほも、ど9ら二しむでくつもだらあいかまごで不なび《そろをして、へ出て行るだ。」そしてろう一郎は？
# 「あらないて。出していってぶっこれでを何
#
# -----diveristy 1.2
# ----- Seedを生成しました: "つなみのような音がして、一ぺんに夕立がやって来ました。風までひゅうひゅう吹きだし"
#
#
#
#
# 　19は机のじめつくつって行きますと、またばさ四ほどからうよと馬の高い粘　かべはあり雨しましたが、雨所《そ》はし
#
# --------------------------------------------------
# 繰り返し回数:  13
# Epoch 1/1
# 10496/11022 [===========================>..] - ETA: 0s - loss: 0.9998
# 11022/11022 [==============================] - 9s 794us/step - loss: 1.0063
#
# -----diveristy 0.2
# ----- Seedを生成しました: "」なんて言っているようでした。
# 　嘉助はあんまり見っともなかったので、目をつむ"
# 」なんて言っているようでした。
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 　みんなはひざって一さんは
#
# -----diveristy 0.5
# ----- Seedを生成しました: "」なんて言っているようでした。
# 　嘉助はあんまり見っともなかったので、目をつむ"
# 」なんて言っているようでした。
#
#
# 「そんだ、あいさが。」と言い
# 「おう
#
# -----diveristy 1.0
# ----- Seedを生成しました: "」なんて言っているようでした。
# 　嘉助はあんまり見っともなかったので、目をつむ"
# 」なんて言っているようでした。
#
#
#
#
#
# 　空がさい雲がおこのになりながらいやりどきのうしろのおじぶま
#
# -----diveristy 1.2
# ----- Seedを生成しました: "」なんて言っているようでした。
# 　嘉助はあんまり見っともなかったので、目をつむ"
# 」なんて言っているようでした。
#
# 　みんなはひろ　ま集上くって藁たがいいがみなさなが押その年生の人は戸ゃんを［毛》ゃわって、まるでもうもないちへはいててにかさんはこ
# の叫ん飛た言い
# 「先生、風た外んだける雲もっが、下《はぽ
#
# --------------------------------------------------
# 繰り返し回数:  14
# Epoch 1/1
# 11022/11022 [==============================] - 9s 800us/step - loss: 0.8881
#
# -----diveristy 0.2
# ----- Seedを生成しました: "。一郎もつかまりました。嘉助がひとり、上をまわって泳いで逃げましたら、三郎はすぐ"
# 「あ、あいて、だっちはもうしてやったよう
#
# -----diveristy 0.5
# ----- Seedを生成しました: "。一郎もつかまりました。嘉助がひとり、上をまわって泳いで逃げましたら、三郎はすぐ"
#
#
#
#
#
#
#
#
#
#
#
#
# 「おおいって来たのです。」と言ってがらまえききりきのほうとうしてくとるでだぞ。いって来たのです。」と言いまし
#
# -----diveristy 1.0
# ----- Seedを生成しました: "。一郎もつかまりました。嘉助がひとり、上をまわって泳いで逃げましたら、三郎はすぐ"
#
# をらぐ上さいが。」
# 「なんて、馬のテ、来たぞの木ごちょうやってこんでした。その出して草を砂んとうぶっちのにいて、風を入ぐちへテちびだのにはかまたようにそってり号つえてひこ助をちょうご三郎が
#
# -----diveristy 1.2
# ----- Seedを生成しました: "。一郎もつかまりました。嘉助がひとり、上をまわって泳いで逃げましたら、三郎はすぐ"
#
#
#
#
#
#
#
#
#
# 「ころくだから出て来た。だっだがどばったぞ。」みんは一生かに雑もやわりおろし
#
# --------------------------------------------------
# 繰り返し回数:  15
# Epoch 1/1
#  1408/11022 [==>...........................] - ETA: 7s - loss: 0.6650
# 11022/11022 [==============================] - 9s 800us/step - loss: 0.7901
#
# -----diveristy 0.2
# ----- Seedを生成しました: "あんまり川をにごすなよ、
# 　いつでも先生言うでないか。」
# 　その人はあわてた"
# あんまり川をにごすなよ、
# 　いつでも先生言うでないか。」
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「お
#
# -----diveristy 0.5
# ----- Seedを生成しました: "あんまり川をにごすなよ、
# 　いつでも先生言うでないか。」
# 　その人はあわてた"
# あんまり川をにごすなよ、
# 　いつでも先生言うでないか。」
# 　その人はあわてた。」と言いながら一生けん命との室のをまたます。」と言いま
# 　外で、先生言ううすきが。まるではだっと見ないな。」と言いなが
#
# -----diveristy 1.0
# ----- Seedを生成しました: "あんまり川をにごすなよ、
# 　いつでも先生言うでないか。」
# 　その人はあわてた"
# あんまり川をにごすなよ、
# 　いつでも先生言うでないか。」
#
#
#
#
#
#
#
# 　いつもどら暑どもややがしてやっていてのとい
#
# -----diveristy 1.2
# ----- Seedを生成しました: "あんまり川をにごすなよ、
# 　いつでも先生言うでないか。」
# 　その人はあわてた"
# あんまり川をにごすなよ、
# 　いつでも先生言うでないか。」
# 　その人はあわてた。目のだあると風が、てラ目いぞ。うんとうに、するどそのといようように、たずだ。」と一郎は
# 　　　うんつわりやっと先生がケって一ぺん足《見ますか雲。」三郎は雨もほうへ、耕助はぶんとじさかに、てころのでした。その向ちも：れて、ほんとはいそれに声んだわしあっちになり、風はじんだんで土手とならいに叫ぶな終たので、またつし
#
# --------------------------------------------------
# 繰り返し回数:  16
# Epoch 1/1
# 11022/11022 [==============================] - 9s 797us/step - loss: 0.7103
#
# -----diveristy 0.2
# ----- Seedを生成しました: "んなもまるでせっかく友だちになった子うまが遠くへやられたよう、せっかく捕《と》っ"
#
#
#
# 　みんなはだんとうんとしていといて、だいや。」と言いながらま
# -----diveristy 0.5
# ----- Seedを生成しました: "んなもまるでせっかく友だちになった子うまが遠くへやられたよう、せっかく捕《と》っ"
#
#
#
#
#
#
#
#
#
#
#
# 　一郎はひこんとうに立っています。それでして、黒い大きを見て鼻のして一郎がけて、
#
# -----diveristy 1.0
# ----- Seedを生成しました: "んなもまるでせっかく友だちになった子うまが遠くへやられたよう、せっかく捕《と》っ"
#
#
# 「お早こやもやや》がやっとみんな。」と言いながらまったりして草からはありきがそれを通りに川ずたてて言いなが
# 　すると一郎が言いました。やっきだけってのって
#
# -----diveristy 1.2
# ----- Seedを生成しました: "んなもまるでせっかく友だちになった子うまが遠くへやられたよう、せっかく捕《と》っ"
#
#
#
#
# けって
#
# --------------------------------------------------
# 繰り返し回数:  17
# Epoch 1/1
#  7680/11022 [===================>..........] - ETA: 2s - loss: 0.6001
# 11022/11022 [==============================] - 9s 808us/step - loss: 0.6500
#
# -----diveristy 0.2
# ----- Seedを生成しました: "出して、五年生と六年生の人は国語の本を出してください。」
# 　さあするとあっちで"
# 出して、五年生と六年生の人は国語の本を出してください。」
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「
#
# -----diveristy 0.5
# ----- Seedを生成しました: "出して、五年生と六年生の人は国語の本を出してください。」
# 　さあするとあっちで"
# 出して、五年生と六年生の人は国語の本を出してください。」
#
# 「おおいれな、だっ、あり、向こうの。たずまっきるやで、あと、又三郎、たの
# 「お早らしっ
#
# -----diveristy 1.0
# ----- Seedを生成しました: "出して、五年生と六年生の人は国語の本を出してください。」
# 　さあするとあっちで"
# 出して、五年生と六年生の人は国語の本を出してください。」
#
#
#
#
#
#
#
#
# 　佐太郎はまっ黒い字はの木はいましたが、白い来なおが、いやぞが又三郎び忘るそうでまいました。
#
# -----diveristy 1.2
# ----- Seedを生成しました: "出して、五年生と六年生の人は国語の本を出してください。」
# 　さあするとあっちで"
# 出して、五年生と六年生の人は国語の本を出してください。」
# 　さあするとあっちでやことのだのろうようにトらさいさ東がらいないが、言いましたが、それが馬は何かぶこ集して気一郎一郎のように叫びましたが、また来てしていま
# 「わあ、あたほやら煙へ噴ね上の抜へ指
#
# --------------------------------------------------
# 繰り返し回数:  18
# Epoch 1/1
# 11022/11022 [==============================] - 9s 794us/step - loss: 0.6017
#
# -----diveristy 0.2
# ----- Seedを生成しました: "》ぐちで顔をふいていたのです。
# 「わあい、又三郎何する。」耕助はうらめしそうに"
# 》ぐちで顔をふいていたのです。
#
#
#
#
#
#
#
#
# 「さあ、この
# 　そこはたくといまもみないで
#
# -----diveristy 0.5
# ----- Seedを生成しました: "》ぐちで顔をふいていたのです。
# 「わあい、又三郎何する。」耕助はうらめしそうに"
# 》ぐちで顔をふいていたのです。
#
#
#
#
#
#
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "》ぐちで顔をふいていたのです。
# 「わあい、又三郎何する。」耕助はうらめしそうに"
# 》ぐちで顔をふいていたのです。
# 「わあい、又三郎何する。」耕助はうらめしそうにばかさあにちゃんと水を見て、ましたのほうで歩いで、いちどものあと一年生のル、言いたがら歩
# 「あ、かっあり川へフばらいませで。わっていましたが、太郎は、どき向こらも顔を二年生けるるはるとそれをといて、見はやりききときのともとそのかすとをとっ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "》ぐちで顔をふいていたのです。
# 「わあい、又三郎何する。」耕助はうらめしそうに"
# 》ぐちで顔をふいていたのです。
#
#
# 「さあ又三郎がようさん喜こころよう、どをも河原へいつもの黒いるがして、上はかれから馬はやっとして
# べくなりが三郎はまたきの子のようにすいでせんましたが、すると三郎は毛るやら学校だゃ。」とみんなのにちゃんとになりて、ここま袖けか気あいましたから、こ魚かぶました。待っていの大二二人、ほんかる追も沿帳
#
# --------------------------------------------------
# 繰り返し回数:  19
# Epoch 1/1
# 11022/11022 [==============================] - 9s 798us/step - loss: 0.5484
#
# -----diveristy 0.2
# ----- Seedを生成しました: "ているのです。
# 「この馬みんな千円以上するづもな。来年がらみんな競馬さも出はる"
# ているのです。
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: "ているのです。
# 「この馬みんな千円以上するづもな。来年がらみんな競馬さも出はる"
# ているのです。
#
# 　　　　　　　　　　　　それからはもったのほうでどろもうのほうもおらしていましたが、どれからみんなはだまって三郎につからもないで教室のは、とは白く見っています。すると嘉助が、ど
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "ているのです。
# 「この馬みんな千円以上するづもな。来年がらみんな競馬さも出はる"
# ているのです。
#
# 「はみなら嘉助も見ましたったようになりました。そして何かすめしたびって神っていたのかす。その人はみんな嘉馬の向こで通く考つして、言いませんかしました。けれども三郎は、どれども時の赤くざいました。そしてこのようで号ど」んつもうわた　ところよと、うと言叫ましたが、それはあと上かやっちへもいって一本のうへはだらない大きなべたのごの顔を大くなに
# 　はる
#
# -----diveristy 1.2
# ----- Seedを生成しました: "ているのです。
# 「この馬みんな千円以上するづもな。来年がらみんな競馬さも出はる"
# ているのです。
#
#
#
#
#
#
# 「お早もだい。どもやども。おと一さあい。ひとけんたてたのが、川は大きなさいきちのとうとみんなもなが風をトを外け出て、うとき生の言いなんといろように歩てなんからやめって一っちを見な
#
# --------------------------------------------------
# 繰り返し回数:  20
# Epoch 1/1
# 11022/11022 [==============================] - 9s 795us/step - loss: 0.5223
#
# -----diveristy 0.2
# ----- Seedを生成しました: "てころんでしまいました。
# 　みんなは、わあわあ叫んで、吉郎をはねこえたり、水に"
# てころんでしまいました。
# 　みんなは、わあわあ叫んで、吉郎をはねこえたり、水には一年生の人のほう
# 　三郎はいっとおじいていましたが、それからそのかんとおりがって
#
# -----diveristy 0.5
# ----- Seedを生成しました: "てころんでしまいました。
# 　みんなは、わあわあ叫んで、吉郎をはねこえたり、水に"
# てころんでしまいました。
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「うん。あのあ。あぶさんなった。」三郎は
#
# -----diveristy 1.0
# ----- Seedを生成しました: "てころんでしまいました。
# 　みんなは、わあわあ叫んで、吉郎をはねこえたり、水に"
# てころんでしまいました。
#
#
# 「--》、に歩ださんは泳かにはどうん二どいろち競をつますた。ところがその前
#
#
# -----diveristy 1.2
# ----- Seedを生成しました: "てころんでしまいました。
# 　みんなは、わあわあ叫んで、吉郎をはねこえたり、水に"
# てころんでしまいました。
#
#
#
#
#
#
#
#
#
# 　三郎は大き
#
# --------------------------------------------------
# 繰り返し回数:  21
# Epoch 1/1
# 11022/11022 [==============================] - 9s 796us/step - loss: 0.4771
#
# -----diveristy 0.2
# ----- Seedを生成しました: "ゃんと打ち合わせて、だあ、と言いました。
# 　するとにわかに七匹ともまるでたてが"
# ゃんと打ち合わせて、だあ、と言いました。
#
# 「あ
# 　そこはたうとうったりそっちを見ていましたが、そ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "ゃんと打ち合わせて、だあ、と言いました。
# 　するとにわかに七匹ともまるでたてが"
# ゃんと打ち合わせて、だあ、と言いました。
#
#
#
#
#
#
#
#
#
#
#
# 　それからその嘉ははいって来ていまったのですから、いちもみんなのうしろでき
#
# -----diveristy 1.0
# ----- Seedを生成しました: "ゃんと打ち合わせて、だあ、と言いました。
# 　するとにわかに七匹ともまるでたてが"
# ゃんと打ち合わせて、だあ、と言いました。
#
# 　又三郎が来たやった年って、先生のうしろから《こまえにするのうよろきどうからみんな高で言いながら、だっちがんこうにどろから
# 「あたひな。ぺあざああ無又三郎吹おて来てぐぐいいと
#
# -----diveristy 1.2
# ----- Seedを生成しました: "ゃんと打ち合わせて、だあ、と言いました。
# 　するとにわかに七匹ともまるでたてが"
# ゃんと打ち合わせて、だあ、と言いました。
#
#
#
#
#
#
# 「先生けんだすとやっと》を見て、そらだりと四年っと高く飛いおっし指をにろなり》をして、またガゃわこあがあらいませんどてしてするのいで柱いでいみんなようにして顔がくなり、まえてが
#
# --------------------------------------------------
# 繰り返し回数:  22
# Epoch 1/1
#  6528/11022 [================>.............] - ETA: 3s - loss: 0.3956
# 11022/11022 [==============================] - 9s 796us/step - loss: 0.4375
#
# -----diveristy 0.2
# ----- Seedを生成しました: "［＃］：入力者注　主に外字の説明や、傍点の位置の指定
# （例）じゃみ［＃「じゃみ"
# ［＃］：入力者注　主に外字の説明や、傍点の位置の指定
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: "［＃］：入力者注　主に外字の説明や、傍点の位置の指定
# （例）じゃみ［＃「じゃみ"
# ［＃］：入力者注　主に外字の説明や、傍点の位置の指定
# （例）じゃみ［＃「じゃみ青さやき上》すす。そして、とうとうに立って、たのへはじめました。一郎
# 「んますか
#
# -----diveristy 1.0
# ----- Seedを生成しました: "［＃］：入力者注　主に外字の説明や、傍点の位置の指定
# （例）じゃみ［＃「じゃみ"
# ［＃］：入力者注　主に外字の説明や、傍点の位置の指定
#
#
#
#
#
#
#
#
#
#
# 「そんだ、ああかわa一つよろ、すぐ、女けおさしめのといっちの顔を吹なら、だまだました。けれど
#
# -----diveristy 1.2
# ----- Seedを生成しました: "［＃］：入力者注　主に外字の説明や、傍点の位置の指定
# （例）じゃみ［＃「じゃみ"
# ［＃］：入力者注　主に外字の説明や、傍点の位置の指定
#
#
# 「方、あざなが音た二だ。」と言いながら上のぐ忙にそうとうとしずしたそに行くとみびにの大人に行く馬
# 　耕助、日さって学かだぞ。黒いそれを黒いっちょにはいってしましたが、やを集れに飛ぶん子の行って、ぼっとりにめ、まんゃかわかったよかにして、底数
#
# --------------------------------------------------
# 繰り返し回数:  23
# Epoch 1/1
# 11022/11022 [==============================] - 9s 807us/step - loss: 0.4094
#
# -----diveristy 0.2
# ----- Seedを生成しました: "どう、どうどう。」と言いながら一生けん命走って行って、やっとそこへ着いてまるでこ"
#
#
# 「おうもみんなはひろ
# 　す
#
# -----diveristy 0.5
# ----- Seedを生成しました: "どう、どうどう。」と言いながら一生けん命走って行って、やっとそこへ着いてまるでこ"
#
#
#
#
#
#
#
#
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "どう、どうどう。」と言いながら一生けん命走って行って、やっとそこへ着いてまるでこ"
#
#
#
# 　はじめはしろ
# 　そのうとと一郎の河原の小さきますか。」みんなぎは一本のに前ま
#
# -----diveristy 1.2
# ----- Seedを生成しました: "どう、どうどう。」と言いながら一生けん命走って行って、やっとそこへ着いてまるでこ"
#
#
#
#
#
#
# 　吉ばったりよこえるとそれをつけは男ほうからみんなとなりがえにそ本へゃるふとぼる戻らうとうビる嘉助とすぐすぐ食みむくし
#
# --------------------------------------------------
# 繰り返し回数:  24
# Epoch 1/1
#  8064/11022 [====================>.........]
# 11022/11022 [==============================] - 9s 796us/step - loss: 0.3944
#
# -----diveristy 0.2
# ----- Seedを生成しました: "るで丈《たけ》ぐらいある草をわけて高みになったり低くなったり、どこまでも走りまし"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 　三郎はじっとさっちへ帰っ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "るで丈《たけ》ぐらいある草をわけて高みになったり低くなったり、どこまでも走りまし"
#
#
#
# 　三郎はじっとみんなのでし
# 「それがた。」三郎がおいました。それから、と
#
# -----diveristy 1.0
# ----- Seedを生成しました: "るで丈《たけ》ぐらいある草をわけて高みになったり低くなったり、どこまでも走りまし"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 　佐太郎はまるする赤《かり》になって明って行うす。のたむとうわ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "るで丈《たけ》ぐらいある草をわけて高みになったり低くなったり、どこまでも走りまし"
#
#
#
# 　その行きました。そしてばそれをたりましな。嘉助がさたにはかかにさい疲子のか、淵《ふっ》へはいつだしな顔を書い、と
# 　横こは鳴りだけっていこでも木の向こうのときっばしたりそっちへ帰りてきました。そして四年生の人はは
#
# --------------------------------------------------
# 繰り返し回数:  25
# Epoch 1/1
# 11022/11022 [==============================] - 9s 783us/step - loss: 0.3709
#
# -----diveristy 0.2
# ----- Seedを生成しました: "言いました。
# 「きょうはみなさんは通信簿と宿題をもってくるのでしたね。持って来"
# 言いました。
#
#
#
#
#
#
#
#
# 「おおいれなあ一郎がない。それ
# 「おう、あとみんなは
#
# -----diveristy 0.5
# ----- Seedを生成しました: "言いました。
# 「きょうはみなさんは通信簿と宿題をもってくるのでしたね。持って来"
# 言いました。
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「おおいれなあ一郎が、あああり雨がたた、だ。
#
# -----diveristy 1.0
# ----- Seedを生成しました: "言いました。
# 「きょうはみなさんは通信簿と宿題をもってくるのでしたね。持って来"
# 言いました。
#
#
#
# 「ああひらうなみな　」一郎がききうけました
# 「そらまり行くはあっていたのです。いれともみんなようにしてれるのです「うかい、あんなよう簑た。あの学校白、やって見たがらないがしました。そしてと2三郎が向こうで見たょではみんなが霧のほうとはくにそうでごぼくっ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "言いました。
# 「きょうはみなさんは通信簿と宿題をもってくるのでしたね。持って来"
# 言いました。
#
#
#
#
#
# 「ああ追いでなぞ。」ときろは高くぶんとはちのまわりきにめと嘉助とすぐわり、ひろも大さっき人のをかけ出してらっこ出してみんなんで西別の入れかに棒かに
# 「なんだ、れ、は列んつ
#
# --------------------------------------------------
# 繰り返し回数:  26
# Epoch 1/1
# 11022/11022 [==============================] - 9s 792us/step - loss: 0.3427
#
# -----diveristy 0.2
# ----- Seedを生成しました: "にばしゃばしゃふっているのです。
# 「この馬みんな千円以上するづもな。来年がらみ"
# にばしゃばしゃふっているのです。
#
#
#
#
#
#
#
#
#
#
# 　それからはいって
# 「わあ、このあたりは、、くた
#
# -----diveristy 0.5
# ----- Seedを生成しました: "にばしゃばしゃふっているのです。
# 「この馬みんな千円以上するづもな。来年がらみ"
# にばしゃばしゃふっているのです。
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「中はするといって、
#
# -----diveristy 1.0
# ----- Seedを生成しました: "にばしゃばしゃふっているのです。
# 「この馬みんな千円以上するづもな。来年がらみ"
# にばしゃばしゃふっているのです。
#
#
#
#
# 　一郎のにいさんでみんなはわくふくしきました。うしろでばたほうがらのみんな発はひろくッげち
# 　　　とったらもあそれからあありきせんできの下のもぶの
#
# -----diveristy 1.2
# ----- Seedを生成しました: "にばしゃばしゃふっているのです。
# 「この馬みんな千円以上するづもな。来年がらみ"
# にばしゃばしゃふっているのです。
#
#
#
#
#
#
#
#
#
#
#
#
# 「先生、少
#
# --------------------------------------------------
# 繰り返し回数:  27
# Epoch 1/1
# 10624/11022 [===========================>..] - ETA: 0s - loss: 0.3343
# 11022/11022 [==============================] - 9s 800us/step - loss: 0.3389
#
# -----diveristy 0.2
# ----- Seedを生成しました: "んなもさわぎながらとにかく立ちあがり、一郎がいちばんうしろで、
# 「礼。」と言い"
# んなもさわぎながらとにかく立ちあがり、一郎がいちばんうしろで、
#
#
#
#
#
#
#
#
# 　すると三郎は、どっと
#
# -----diveristy 0.5
# ----- Seedを生成しました: "んなもさわぎながらとにかく立ちあがり、一郎がいちばんうしろで、
# 「礼。」と言い"
# んなもさわぎながらとにかく立ちあがり、一郎がいちばんうしろで、
#
# 　そのかまは一年生のほうへ一つのになった、
# た言いたがなんで、足をはいれしたそしてみんなの前まりまわしてしんかしてから、風を出して来てっていました。そして来て三郎はいって来て窓ガはいたほて来て来ました。そして、とうからもとって出て来て来て、またがたばた所ころ
#
# -----diveristy 1.0
# ----- Seedを生成しました: "んなもさわぎながらとにかく立ちあがり、一郎がいちばんうしろで、
# 「礼。」と言い"
# んなもさわぎながらとにかく立ちあがり、一郎がいちばんうしろで、
#
#
#
#
#
# 「うん。その持って来てだぞ。おと嘉助が旗、そのだ
# んだんかす、やっと先さは半いとみんなのすぐの前をこっちを見ていましたが、びたがやみんなはありました。にかるが鳴り、やったりさにかりました。みんなさそ所はの泣かの大きなら
#
# -----diveristy 1.2
# ----- Seedを生成しました: "んなもさわぎながらとにかく立ちあがり、一郎がいちばんうしろで、
# 「礼。」と言い"
# んなもさわぎながらとにかく立ちあがり、一郎がいちばんうしろで、
# 「礼。」と言いましたが、十団は、きぐしてい。」と言いました。として先生について行く、　の前ですねずって出　」と言いだがそれからじとが青じさがいました。一郎は風の黒いたくだぶだかの向こうのごと立ってまたまわして、通っとお間も気ちばたり、またひったのですましました。わしわくないでした。そのうのとうさんげんだいや、みんなお早塵水に飛ていませしした。けかに、れをかんつ馬しけばら学ここを忘し嘉助、みんな唱まるで丸かなそした。そのりがみんなはここ早くも大ゃな所が気大きな書に、きましたので、一郎は木の浅を青くれる秋」として立って来たのですかし、かりました。郎がさ吉黒いれてそのを
# 　黒い大どやどばら上のほうの子の忙るで大きなりでした。黒いか教ルのさいきて河原の前のすこめに　か
#
# --------------------------------------------------
# 繰り返し回数:  28
# Epoch 1/1
# 11022/11022 [==============================] - 9s 797us/step - loss: 0.3213
#
# -----diveristy 0.2
# ----- Seedを生成しました: "っきの小高いところをまわって、さっき五人ではいって来たどての切れた所へ来たのです"
#
#
#
#
#
#
#
#
# 「おまえていさ
# 　み
#
# -----diveristy 0.5
# ----- Seedを生成しました: "っきの小高いところをまわって、さっき五人ではいって来たどての切れた所へ来たのです"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「又三郎びって来たが。
#
# -----diveristy 1.0
# ----- Seedを生成しました: "っきの小高いところをまわって、さっき五人ではいって来たどての切れた所へ来たのです"
#
#
#
#
#
# 　すると三郎は顔いなのもじな大人も雨がすおって来た。たばたがこごのとでぞ。水
#
#
# 　三
# 「うん。いますか。すると三郎に、上げせんではじぶんしてしますちのか、といさん水の中ではちょ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "っきの小高いところをまわって、さっき五人ではいって来たどての切れた所へ来たのです"
#
#
#
#
#
#
#
#
#
#
# 　三人は日っしょには三郎て寄るを見て急みころのぽでみなさんもうつむばら赤い手をがし
#
# --------------------------------------------------
# 繰り返し回数:  29
# Epoch 1/1
#  9984/11022 [==========================>...] - ETA: 0s - loss: 0.3135
# 11022/11022 [==============================] - 9s 795us/step - loss: 0.3252
#
# -----diveristy 0.2
# ----- Seedを生成しました: "ながめました。
# 　光ったりかげったり幾通りにも重なったたくさんの丘の向こうに、"
# ながめました。
#
#
#
#
#
#
#
#
#
#
# 　みんなはどんとうにして、また言いましたが、
#
# -----diveristy 0.5
# ----- Seedを生成しました: "ながめました。
# 　光ったりかげったり幾通りにも重なったたくさんの丘の向こうに、"
# ながめました。
#
# 　みんなはどんとうに川ころのけでしたら、河原のおいました。そのう
# 「あああいであ
#
# -----diveristy 1.0
# ----- Seedを生成しました: "ながめました。
# 　光ったりかげったり幾通りにも重なったたくさんの丘の向こうに、"
# ながめました。
#
#
#
#
#
#
#
# 「おおいれななみなさな。」と言いながら白い川は者いていました。と言わがらないな。
#
# -----diveristy 1.2
# ----- Seedを生成しました: "ながめました。
# 　光ったりかげったり幾通りにも重なったたくさんの丘の向こうに、"
# ながめました。
#
#
#
#
# 「お
# 　すると思いっら、またはくはてはだんだんか馬と歩まえした。耕助は叫びました。としろが「ろよなようでした。そして
#
# --------------------------------------------------
# 繰り返し回数:  30
# Epoch 1/1
# 11022/11022 [==============================] - 9s 799us/step - loss: 0.2960
#
# -----diveristy 0.2
# ----- Seedを生成しました: "う四年生ど六年生だな。」
# 　嘉助は大急ぎで教室をはねだして逃げてしまいました。"
# う四年生ど六年生だな。」
#
#
#
#
# 　それからその机の上がいて来たぞ。」二助がさいやってくかって、その下へはいるのだぶっとして、
# 「風が嘉助、あら西
#
# -----diveristy 0.5
# ----- Seedを生成しました: "う四年生ど六年生だな。」
# 　嘉助は大急ぎで教室をはねだして逃げてしまいました。"
# う四年生ど六年生だな。」
#
#
#
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "う四年生ど六年生だな。」
# 　嘉助は大急ぎで教室をはねだして逃げてしまいました。"
# う四年生ど六年生だな。」
# 「又三
#
# -----diveristy 1.2
# ----- Seedを生成しました: "う四年生ど六年生だな。」
# 　嘉助は大急ぎで教室をはねだして逃げてしまいました。"
# う四年生ど六年生だな。」
#
#
#
# 　五年生の人のも、追もうでしてしまったた時ぼって、ばわりませ佐かってのっし
#
# --------------------------------------------------
# 繰り返し回数:  31
# Epoch 1/1
#  4352/11022 [==========>...................] - ETA: 5s - loss: 0.2280
# 11022/11022 [==============================] - 9s 794us/step - loss: 0.2794
#
# -----diveristy 0.2
# ----- Seedを生成しました: "にはいるとすぐその持ったものを、さいかちの木の下のところへ投げこみました。すると"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「おう、どれ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "にはいるとすぐその持ったものを、さいかちの木の下のところへ投げこみました。すると"
#
#
#
# 「おおい知なあ
# -----diveristy 1.0
# ----- Seedを生成しました: "にはいるとすぐその持ったものを、さいかちの木の下のところへ投げこみました。すると"
#
#
#
#
#
#
#
#
#
# 「お早う。」と一思の言
#
# -----diveristy 1.2
# ----- Seedを生成しました: "にはいるとすぐその持ったものを、さいかちの木の下のところへ投げこみました。すると"
#
#
# 「わあい、けんで、馬あすぐ、するの小さな葡ふいなな。」みんないさんも会の中であるあらいって来てこんどんは四年生と激っな、言いながらくも丸いつきを見ていましたが
# --------------------------------------------------
# 繰り返し回数:  32
# Epoch 1/1
# 11022/11022 [==============================] - 9s 797us/step - loss: 0.2764
#
# -----diveristy 0.2
# ----- Seedを生成しました: "けれどもやっぱり底まで届かずに浮いてきたのでみんなはどっと笑いました。そのとき向"
#
#
#
#
#
#
#
#
#
# 　そこ
# 　三郎
#
# -----diveristy 0.5
# ----- Seedを生成しました: "けれどもやっぱり底まで届かずに浮いてきたのでみんなはどっと笑いました。そのとき向"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "けれどもやっぱり底まで届かずに浮いてきたのでみんなはどっと笑いました。そのとき向"
#
#
#
#
#
#
#
# 　嘉助はやっうんけんでしてて、そうちんだのみ
# 　みんなは先生の向きらくみなさんがいま急ぎて、まる三人に肌さ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "けれどもやっぱり底まで届かずに浮いてきたのでみんなはどっと笑いました。そのとき向"
#
#
#
#
#
#
#
#
# 　ところが五のそうからども
#
# --------------------------------------------------
# 繰り返し回数:  33
# Epoch 1/1
# 11022/11022 [==============================] - 9s 798us/step - loss: 0.2559
#
# -----diveristy 0.2
# ----- Seedを生成しました: "。嘉助。」一郎の声もしました。嘉助はよろこんでとびあがりました。
# 「おおい。い"
# 。嘉助。」一郎の声もしました。嘉助はよろこんでとびあがりました。
# 「おおい。いるとは悪ないお早う。」と言いな
# 「うん。うん。どんどてど
#
# -----diveristy 0.5
# ----- Seedを生成しました: "。嘉助。」一郎の声もしました。嘉助はよろこんでとびあがりました。
# 「おおい。い"
# 。嘉助。」一郎の声もしました。嘉助はよろこんでとびあがりました。
#
#
#
#
#
#
#
#
#
#
#
#
# 　三郎はまるであみんなのおいだい
#
# -----diveristy 1.0
# ----- Seedを生成しました: "。嘉助。」一郎の声もしました。嘉助はよろこんでとびあがりました。
# 「おおい。い"
# 。嘉助。」一郎の声もしました。嘉助はよろこんでとびあがりました。
#
# 「そらえ
# 　そのうきろう又三郎おおりの水を赤いてていました。みんなも言いながらのように立って草の中でしたから、もう中しきどれか
#
# -----diveristy 1.2
# ----- Seedを生成しました: "。嘉助。」一郎の声もしました。嘉助はよろこんでとびあがりました。
# 「おおい。い"
# 。嘉助。」一郎の声もしました。嘉助はよろこんでとびあがりました。
#
#
#
#
#
#
# 「上出あ底底けれを
# かぐりなり？
#
# --------------------------------------------------
# 繰り返し回数:  34
# Epoch 1/1
# 11022/11022 [==============================] - 9s 797us/step - loss: 0.2563
#
# -----diveristy 0.2
# ----- Seedを生成しました: "しました。草の中には、今馬と三郎が通った跡らしく、かすかな道のようなものがありま"
#
#
#
#
#
#
#
#
#
#
#
#
# 「なったらこのをあ
# 　すると三郎はにもっとそのうの
#
# -----diveristy 0.5
# ----- Seedを生成しました: "しました。草の中には、今馬と三郎が通った跡らしく、かすかな道のようなものがありま"
#
#
#
#
#
#
#
#
#
#
#
#
#
# 　みんなは一郎かにそれを見え、そ
#
# -----diveristy 1.0
# ----- Seedを生成しました: "しました。草の中には、今馬と三郎が通った跡らしく、かすかな道のようなものがありま"
#
#
#
#
#
#
# 「それ、それが、いって来たらなありがありました。それを
# 　みんなはだんましからって来だぞ。」と言いながら子のときさは
#
# -----diveristy 1.2
# ----- Seedを生成しました: "しました。草の中には、今馬と三郎が通った跡らしく、かすかな道のようなものがありま"
#
#
#
#
#
#
#
#
#
#
# 　みんなはすぐりしめくくなったちのがありませんでしたのですけ見で、栗《か》をしってやややのほうです。みんなあ《ふい》し
#
# --------------------------------------------------
# 繰り返し回数:  35
# Epoch 1/1
# 11022/11022 [==============================] - 9s 797us/step - loss: 0.2523
#
# -----diveristy 0.2
# ----- Seedを生成しました: "らやっぱりきのうのように暑くなりました。みんなはもう授業の済むのばかり待っていま"
#
# 　みんなはどんとは下へ
# 「ないおいさん、来たったりして、あからんないで馬。」一郎の前のほうへ出
#
# -----diveristy 0.5
# ----- Seedを生成しました: "らやっぱりきのうのように暑くなりました。みんなはもう授業の済むのばかり待っていま"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「おう、馬の葉る。どょうやしてけれ、あり気がなぐ。
#
# -----diveristy 1.0
# ----- Seedを生成しました: "らやっぱりきのうのように暑くなりました。みんなはもう授業の済むのばかり待っていま"
#
#
#
#
# 　三のっ
# 「こ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "らやっぱりきのうのように暑くなりました。みんなはもう授業の済むのばかり待っていま"
#
#
#
#
#
#
#
#
#
#
# 「まるあげる高いって」と鼻は、知らないおぺありあざその
#
# --------------------------------------------------
# 繰り返し回数:  36
# Epoch 1/1
# 11022/11022 [==============================] - 9s 797us/step - loss: 0.2381
#
# -----diveristy 0.2
# ----- Seedを生成しました: "ない、そでない。」みんないっしょに叫びました。
# 　ぺ吉がまた一人出て来て、
# "
# ない、そでない。」みんないっしょに叫びました。
# 　ぺ吉がまた一人出て来て、
# 　すると嘉助はうらじして三郎にすっか
#
# -----diveristy 0.5
# ----- Seedを生成しました: "ない、そでない。」みんないっしょに叫びました。
# 　ぺ吉がまた一人出て来て、
# "
# ない、そでない。」みんないっしょに叫びました。
# 　ぺ吉がまた一人出て来て、
#
#
#
#
#
#
#
#
#
#
#
# 「あが耕ここやはどうやったらないやった。」と言いながら一生けん命とのの下
#
# -----diveristy 1.0
# ----- Seedを生成しました: "ない、そでない。」みんないっしょに叫びました。
# 　ぺ吉がまた一人出て来て、
# "
# ない、そでない。」みんないっしょに叫びました。
# 　ぺ吉がまた一人出て来て、
#
# 「なんだ、ぼるとわから、いまたがもすったのです。」みん
# 「なんだよ。それから、あとこって来たぞ。」と言いました。するとはよろ立っていましたのでみんなもつのまたりにばたほうの木のとうっとそのにきましたのでみん
#
# -----diveristy 1.2
# ----- Seedを生成しました: "ない、そでない。」みんないっしょに叫びました。
# 　ぺ吉がまた一人出て来て、
# "
# ない、そでない。」みんないっしょに叫びました。
# 　ぺ吉がまた一人出て来て、
#
#
#
#
#
#
#
#
# 「ころはおしました。すしように来たり低のごは高くぎったりなさた。」
# 「ぐる。そ
#
# --------------------------------------------------
# 繰り返し回数:  37
# Epoch 1/1
# 11022/11022 [==============================] - 9s 797us/step - loss: 0.2463
#
# -----diveristy 0.2
# ----- Seedを生成しました: "から言いました。
# 「汝《うな》など悪戯《わるさ》ばりさな、傘《かさ》ぶっこわし"
# から言いました。
#
#
#
# 　顔を
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: "から言いました。
# 「汝《うな》など悪戯《わるさ》ばりさな、傘《かさ》ぶっこわし"
# から言いました。
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "から言いました。
# 「汝《うな》など悪戯《わるさ》ばりさな、傘《かさ》ぶっこわし"
# から言いました。
#
#
#
#
#
#
# 　三郎は気
# 　三郎はいっとり早ぐに、
#
# -----diveristy 1.2
# ----- Seedを生成しました: "から言いました。
# 「汝《うな》など悪戯《わるさ》ばりさな、傘《かさ》ぶっこわし"
# から言いました。
#
#
#
#
#
#
# 　その一郎はあぐさて行ったようになるここに立ちがっと急い、四年生の河
#
# --------------------------------------------------
# 繰り返し回数:  38
# Epoch 1/1
# 11022/11022 [==============================] - 9s 798us/step - loss: 0.2148
#
# -----diveristy 0.2
# ----- Seedを生成しました: "　＊
# 　ふと嘉助は目をひらきました。灰いろの霧が速く速く飛んでいます。
# 　そ"
# 　＊
# 　ふと嘉助は目をひらきました。灰いろの霧が速く速く飛んでいます。
# 　そこからまる一っちのはすべするの人の行のとは上の
# 　みんなは淵《ふち》の木が、してしたから、それは風とうっとしてとにおりがしろを出して、風だぶっちの
#
# -----diveristy 0.5
# ----- Seedを生成しました: "　＊
# 　ふと嘉助は目をひらきました。灰いろの霧が速く速く飛んでいます。
# 　そ"
# 　＊
# 　ふと嘉助は目をひらきました。灰いろの霧が速く速く飛んでいます。
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「お早ぎ。さら来るが。よう三郎が先生についてしてうに、一郎をつけて行ららえるぞ。」二
#
# -----diveristy 1.0
# ----- Seedを生成しました: "　＊
# 　ふと嘉助は目をひらきました。灰いろの霧が速く速く飛んでいます。
# 　そ"
# 　＊
# 　ふと嘉助は目をひらきました。灰いろの霧が速く速く飛んでいます。
#
# 「お早》
# 「なんた、だんだ。」と嘉助はうまだ大人な向こうについたほしたが、どんもうもすっぱりしいんと見な「い。」
#
# -----diveristy 1.2
# ----- Seedを生成しました: "　＊
# 　ふと嘉助は目をひらきました。灰いろの霧が速く速く飛んでいます。
# 　そ"
# 　＊
# 　ふと嘉助は目をひらきました。灰いろの霧が速く速く飛んでいます。
#
#
#
#
#
#
# 「お三郎がみんなはだっと気ぞ。えまだい。するとはみんなはね三郎の一生の四二人しな笑ないの子が、たながたが、ま
#
# --------------------------------------------------
# 繰り返し回数:  39
# Epoch 1/1
#   768/11022 [=>............................] - ETA: 8s - loss: 0.1725
# 11022/11022 [==============================] - 9s 786us/step - loss: 0.2227
#
# -----diveristy 0.2
# ----- Seedを生成しました: "、それが玄関の前まで行くと、きりきりとまわって小さなつむじ風になって、黄いろな塵"
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「おうもやいであり。」と言いながら手じびしたが、二年生のだ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "、それが玄関の前まで行くと、きりきりとまわって小さなつむじ風になって、黄いろな塵"
#
#
# 　みんなはもう疲と一
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "、それが玄関の前まで行くと、きりきりとまわって小さなつむじ風になって、黄いろな塵"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----diveristy 1.2
# ----- Seedを生成しました: "、それが玄関の前まで行くと、きりきりとまわって小さなつむじ風になって、黄いろな塵"
#
#
#
#
# 　に《く嘉郎はあるぢゃ。」と言いながら白いつをとってとび
# 「んからまり知はないとかす。」三郎は高く見ってい
#
# --------------------------------------------------
# 繰り返し回数:  40
# Epoch 1/1
# 11022/11022 [==============================] - 9s 797us/step - loss: 0.2191
#
# -----diveristy 0.2
# ----- Seedを生成しました: "わあい、又三郎何する。」耕助はうらめしそうに木を見あげました。
# 「風が吹いたん"
# わあい、又三郎何する。」耕助はうらめしそうに木を見あげました。
#
#
#
#
#
#
#
#
#
#
#
# 「さあい。
# 　はいろうにしてこんもやいやとすぐ目しからったほうもうまえながら手をあぐわしてから、「きなんだい、かよろが嘉助の子どもらへいっ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "わあい、又三郎何する。」耕助はうらめしそうに木を見あげました。
# 「風が吹いたん"
# わあい、又三郎何する。」耕助はうらめしそうに木を見あげました。
#
#
#
#
#
#
#
#
#
# 「さあ、いるな
#
# -----diveristy 1.0
# ----- Seedを生成しました: "わあい、又三郎何する。」耕助はうらめしそうに木を見あげました。
# 「風が吹いたん"
# わあい、又三郎何する。」耕助はうらめしそうに木を見あげました。
#
# 　けっては中それに川《かわ
# -----diveristy 1.2
# ----- Seedを生成しました: "わあい、又三郎何する。」耕助はうらめしそうに木を見あげました。
# 「風が吹いたん"
# わあい、又三郎何する。」耕助はうらめしそうに木を見あげました。
#
#
#
#
#
#
#
#
#
#
#
# 「耕助は前にわっていたかして水に名て二お午《ふい》》をやっともをあいて叫びせんでしたのですいろみんなはどんと草さ秋ねちのほうは六を子っ川顔を答て、また一てもそれ
#
# --------------------------------------------------
# 繰り返し回数:  41
# Epoch 1/1
#  7808/11022 [====================>.........] - ETA: 2s - loss: 0.1828
# 11022/11022 [==============================] - 9s 790us/step - loss: 0.2076
#
# -----diveristy 0.2
# ----- Seedを生成しました: "もおれも、もう死ぬばかりだ。）と嘉助は半分思うように半分つぶやくようにしました。"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 　みな
#
# -----diveristy 0.5
# ----- Seedを生成しました: "もおれも、もう死ぬばかりだ。）と嘉助は半分思うように半分つぶやくようにしました。"
#
#
#
# 　二時は、どうへんはいないがいで、嘉助
# 　三郎はひろくる
#
# -----diveristy 1.0
# ----- Seedを生成しました: "もおれも、もう死ぬばかりだ。）と嘉助は半分思うように半分つぶやくようにしました。"
#
#
#
#
#
#
#
#
#
#
# 「さあは一のように風をついてぱを見ていました。ほうはあといように、一つもいのようにしていましたが、それからぐ三郎が馬の上がして、大人も何ぶな
#
# -----diveristy 1.2
# ----- Seedを生成しました: "もおれも、もう死ぬばかりだ。）と嘉助は半分思うように半分つぶやくようにしました。"
#
# 　馬は顔を下の人に、じゃして砂らんまだんだのか少したのは（れたよとに飛な遊こ気がけいかさなからさなからいました。見てきから」は思いました。ふいとを手ぐに三郎がら棒に向いて顔を
# 　三郎は白いすよかようしろをぞ。高
#
#
# 　二時は
#
# --------------------------------------------------
# 繰り返し回数:  42
# Epoch 1/1
# 11022/11022 [==============================] - 9s 794us/step - loss: 0.2039
#
# -----diveristy 0.2
# ----- Seedを生成しました: "い広場のように見えたのです。
# 　嘉助はがっかりして、黒い道をまた戻りはじめまし"
# い広場のように見えたのです。
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: "い広場のように見えたのです。
# 　嘉助はがっかりして、黒い道をまた戻りはじめまし"
# い広場のように見えたのです。
#
#
#
#
#
# 　三郎はいっとみそれをばてきらいました。そして三
# 「おおださって。」と言ってまた
#
# -----diveristy 1.0
# ----- Seedを生成しました: "い広場のように見えたのです。
# 　嘉助はがっかりして、黒い道をまた戻りはじめまし"
# い広場のように見えたのです。
#
#
#
#
#
#
#
#
#
# 「それはぶっとなさんがやり、　ぎ飛は？」きましたから、とって急いで少した。そして、とう
#
# -----diveristy 1.2
# ----- Seedを生成しました: "い広場のように見えたのです。
# 　嘉助はがっかりして、黒い道をまた戻りはじめまし"
# い広場のように見えたのです。
#
#
# 「年生ろどこと下の、一つと佐太郎《《ぶ》こ》前な顔《ふとううご早き沿気そうでした。そしてかあああぼあえて三へかわかわたきなったといっていました。そして三
# しならだっちどんなばさあ馬みんな一目のあお生
#
# --------------------------------------------------
# 繰り返し回数:  43
# Epoch 1/1
# 11022/11022 [==============================] - 9s 791us/step - loss: 0.1989
#
# -----diveristy 0.2
# ----- Seedを生成しました: "れどもみんな底まで行かないに息がつまって浮かびだして来て、かわるがわるふうとそこ"
#
#
#
#
#
#
# 　耕助は木って行きますぐじめをしんのうちのほうはるのだんだん
# 「お早こや
#
# -----diveristy 0.5
# ----- Seedを生成しました: "れどもみんな底まで行かないに息がつまって浮かびだして来て、かわるがわるふうとそこ"
#
#
#
#
#
#
#
#
#
#
#
# 　みんなはひるそうにと
#
# -----diveristy 1.0
# ----- Seedを生成しました: "れどもみんな底まで行かないに息がつまって浮かびだして来て、かわるがわるふうとそこ"
#
#
#
#
# 「先生、顔をあい、あの前なけこのづちゃな。」と悦ばがさんとうにきろ言いました。みんなはどんこん》のにそらまたみてかりませでで窓のとをわくなく向
# 　みんなはもう疲あ行きてするのだ。
#
# -----diveristy 1.2
# ----- Seedを生成しました: "れどもみんな底まで行かないに息がつまって浮かびだして来て、かわるがわるふうとそこ"
#
#
#
#
#
#
#
#
# 　三郎は向こうのにたいたのほうが先生とにガ「ラ［んはばらぱりました。淵《ふち》を見なく、水へははあの丘してょうや押がん早るそう
#
# --------------------------------------------------
# 繰り返し回数:  44
# Epoch 1/1
# 11022/11022 [==============================] - 9s 778us/step - loss: 0.1942
#
# -----diveristy 0.2
# ----- Seedを生成しました: "はだんだんみんなの道具をしまわせました。
# 　それから「ではここまで。」と言って"
# はだんだんみんなの道具をしまわせました。
#
# 　三郎は、それをすぐじめ
# 「な。」
#
# -----diveristy 0.5
# ----- Seedを生成しました: "はだんだんみんなの道具をしまわせました。
# 　それから「ではここまで。」と言って"
# はだんだんみんなの道具をしまわせました。
#
#
#
#
#
#
#
#
#
#
# 「そんだかあ、あといさん。草れをつ
#
# -----diveristy 1.0
# ----- Seedを生成しました: "はだんだんみんなの道具をしまわせました。
# 　それから「ではここまで。」と言って"
# はだんだんみんなの道具をしまわせました。
#
#
#
# 「礼。一郎は出してむまだいに息も、時ばかりなさったのだそれで来たのですね。みないがいつ口を気れて、そ
# 　三郎は気の　すべ
#
#
#
#
# 　佐太郎はにってこんのとことまた突こ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "はだんだんみんなの道具をしまわせました。
# 　それから「ではここまで。」と言って"
# はだんだんみんなの道具をしまわせました。
#
#
#
#
#
#
#
#
#
#
# 「そんだかみ
#
# --------------------------------------------------
# 繰り返し回数:  45
# Epoch 1/1
#  8576/11022 [======================>.......] - ETA: 1s - loss: 0.1813
# 11022/11022 [==============================] - 9s 773us/step - loss: 0.1922
#
# -----diveristy 0.2
# ----- Seedを生成しました: "に組み付こうとしました。そこで一郎が間へはいって嘉助が耕助を押えてしまいました。"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「あ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "に組み付こうとしました。そこで一郎が間へはいって嘉助が耕助を押えてしまいました。"
#
#
#
# 　三郎はまたふいつかするのかに、れか
# 　みんなはふりながそのほうへやび早く見ていま
#
# -----diveristy 1.0
# ----- Seedを生成しました: "に組み付こうとしました。そこで一郎が間へはいって嘉助が耕助を押えてしまいました。"
#
#
#
#
#
#
#
#
#
#
#
#
#
# 　みないて一生りまっち《さな》がするふかびあし、そばがりに行がきました。みんな
#
# -----diveristy 1.2
# ----- Seedを生成しました: "に組み付こうとしました。そこで一郎が間へはいって嘉助が耕助を押えてしまいました。"
#
#
#
# 　みんなそのほうへははした来た顔を
# 「ああひう雨は鳴
#
# --------------------------------------------------
# 繰り返し回数:  46
# Epoch 1/1
# 11022/11022 [==============================] - 9s 783us/step - loss: 0.1796
#
# -----diveristy 0.2
# ----- Seedを生成しました: "いましたら、また腹かけから何か出しました。
# 「発破《はっぱ》だぞ、発破だぞ。」"
# いましたら、また腹かけから何か出しました。
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: "いましたら、また腹かけから何か出しました。
# 「発破《はっぱ》だぞ、発破だぞ。」"
# いましたら、また腹かけから何か出しました。
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 　みんなは淵《ふち》の木に叫って、そのがらはだまってのって一つの顔を投てねらいました。一郎は急いへ歩ま
# 　一郎が気んな。　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　ふふ
#
# -----diveristy 1.0
# ----- Seedを生成しました: "いましたら、また腹かけから何か出しました。
# 「発破《はっぱ》だぞ、発破だぞ。」"
# いましたら、また腹かけから何か出しました。
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「
#
# -----diveristy 1.2
# ----- Seedを生成しました: "いましたら、また腹かけから何か出しました。
# 「発破《はっぱ》だぞ、発破だぞ。」"
# いましたら、また腹かけから何か出しました。
#
#
# 「なんが、じぶんとあり向
# 「やん（んだ、売魚は変かとおうしろこちへ風がないて
#
# --------------------------------------------------
# 繰り返し回数:  47
# Epoch 1/1
# 11022/11022 [==============================] - 8s 769us/step - loss: 0.1812
#
# -----diveristy 0.2
# ----- Seedを生成しました: "も残りの雲が湯げのように立ちました。
# 「下がったら葡萄蔓《えびづる》とりに行が"
# も残りの雲が湯げのように立ちました。
#
#
#
#
#
#
#
#
#
# 　五
# 　ほんはうっと前のほうへはいて行きました
#
# -----diveristy 0.5
# ----- Seedを生成しました: "も残りの雲が湯げのように立ちました。
# 「下がったら葡萄蔓《えびづる》とりに行が"
# も残りの雲が湯げのように立ちました。
#
#
#
#
#
#
#
#
#
#
#
#
# 「ああ、いさん、あり　に馬か馬さんなら、やっ
#
# -----diveristy 1.0
# ----- Seedを生成しました: "も残りの雲が湯げのように立ちました。
# 「下がったら葡萄蔓《えびづる》とりに行が"
# も残りの雲が湯げのように立ちました。
#
#
# 　空
# 　に少し
#
# -----diveristy 1.2
# ----- Seedを生成しました: "も残りの雲が湯げのように立ちました。
# 「下がったら葡萄蔓《えびづる》とりに行が"
# も残りの雲が湯げのように立ちました。
#
#
#
#
#
#
# 　大人もすった、あいかすわかどないがやっ
#
# --------------------------------------------------
# 繰り返し回数:  48
# Epoch 1/1
# 11022/11022 [==============================] - 8s 764us/step - loss: 0.1785
#
# -----diveristy 0.2
# ----- Seedを生成しました: "の間あのおかしな子は、何かおかしいのかおもしろいのか奥歯で横っちょに舌をかむよう"
# の間あのおかしな子は、何かおかしいのかおもしろいのか奥歯で横っちょに舌をかむようようにやんところを通りま
# 　五年生の人、時間には五年生の人は国」きる《と
#
# -----diveristy 0.5
# ----- Seedを生成しました: "の間あのおかしな子は、何かおかしいのかおもしろいのか奥歯で横っちょに舌をかむよう"
#
#
#
#
#
#
#
#
#
#
#
#
#
# 　一郎が風が言って、
#
# -----diveristy 1.0
# ----- Seedを生成しました: "の間あのおかしな子は、何かおかしいのかおもしろいのか奥歯で横っちょに舌をかむよう"
#
#
#
#
# 「わあ、いましたら
# 「あ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "の間あのおかしな子は、何かおかしいのかおもしろいのか奥歯で横っちょに舌をかむよう"
#
#
#
#
#
#
#
#
#
# 「そんら、あといさん、ごぼんとうに仰いつのに、二年生のほうへ行きまし
#
# --------------------------------------------------
# 繰り返し回数:  49
# Epoch 1/1
# 11022/11022 [==============================] - 8s 771us/step - loss: 0.1715
#
# -----diveristy 0.2
# ----- Seedを生成しました: "まるで落ちついて、立って一あし水にはいるとすぐその持ったものを、さいかちの木の下"
#
# 　三郎はま
# 「先生、「
#
# -----diveristy 0.5
# ----- Seedを生成しました: "まるで落ちついて、立って一あし水にはいるとすぐその持ったものを、さいかちの木の下"
#
#
#
#
#
#
#
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "まるで落ちついて、立って一あし水にはいるとすぐその持ったものを、さいかちの木の下"
#
# 「それからそれから、よろ三郎のだぶっちゃな
# 　それからねまっ白くよ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "まるで落ちついて、立って一あし水にはいるとすぐその持ったものを、さいかちの木の下"
#
#
#
#
#
#
#
#
# 　組一郎がきの前へはいるれもいでしいのと、子わかぼめばありまけました。一郎て行きませできこので（ふい風、あらまた変ないと取っていました。そして三郎もいまり
#
# --------------------------------------------------
# 繰り返し回数:  50
# Epoch 1/1
# 11022/11022 [==============================] - 9s 776us/step - loss: 0.1767
#
# -----diveristy 0.2
# ----- Seedを生成しました: "っかりやらえる。」と一郎のおじいさんがくぐりのところに立って、ぐっと空を見ていま"
# っかりやらえる。」と一郎のおじいさんがくぐりのところに立って、ぐっと空を見ていました。
# 「
#
# -----diveristy 0.5
# ----- Seedを生成しました: "っかりやらえる。」と一郎のおじいさんがくぐりのところに立って、ぐっと空を見ていま"
#
#
#
#
#
#
#
#
#
#
#
#
# 　みんなは淵《ふち》の木のうな一人のほうへやらもくなって
#
# -----diveristy 1.0
# ----- Seedを生成しました: "っかりやらえる。」と一郎のおじいさんがくぐりのところに立って、ぐっと空を見ていま"
#
# 「それなら、それからどながやがす。ゆっちょって来たからすこたりしました。五郎はまるでみんなの馬のほうへやらしてひおら
# 「霧が気がたがやって来た。」と悦人の回っぱりみながらッいようにどそれに、白い出したのです
#
# -----diveristy 1.2
# ----- Seedを生成しました: "っかりやらえる。」と一郎のおじいさんがくぐりのところに立って、ぐっと空を見ていま"
#
#
#
#
#
#
#
#
#
#
# 「あいささ
#
# --------------------------------------------------
# 繰り返し回数:  51
# Epoch 1/1
# 11022/11022 [==============================] - 9s 773us/step - loss: 0.1705
#
# -----diveristy 0.2
# ----- Seedを生成しました: "
# 　嘉助は咽喉《のど》いっぱい叫びました。
# 「一郎、一郎、こっちさ来う。」とこ"
#
# 　嘉助は咽喉《のど》いっぱい叫びました。
# 「一郎、一郎、こっちさ来う。」ところ
# 「であ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "
# 　嘉助は咽喉《のど》いっぱい叫びました。
# 「一郎、一郎、こっちさ来う。」とこ"
#
# 　嘉助は咽喉《のど》いっぱい叫びました。
#
#
#
#
#
#
#
#
#
#
# 　一郎が大人ないがみい、そのうんとしてくちばたくるやったと見ないのと、二人はあるのように立た草のとのかに
#
# -----diveristy 1.0
# ----- Seedを生成しました: "
# 　嘉助は咽喉《のど》いっぱい叫びました。
# 「一郎、一郎、こっちさ来う。」とこ"
#
# 　嘉助は咽喉《のど》いっぱい叫びました。
#
# 「お早うございま
# 　思っならぼっころじめま
#
# -----diveristy 1.2
# ----- Seedを生成しました: "
# 　嘉助は咽喉《のど》いっぱい叫びました。
# 「一郎、一郎、こっちさ来う。」とこ"
#
# 　嘉助は咽喉《のど》いっぱい叫びました。
#
#
#
#
#
#
#
#
#
# 「雲き井ました。又三郎が学のへいら指で魚かりしろのとじぶこうにしてからやったようさました。その高いで顔を鼻のむと言いながら入た口に先生きてねイ供霧た二かみな
#
# --------------------------------------------------
# 繰り返し回数:  52
# Epoch 1/1
#  9600/11022 [=========================>....] - ETA: 1s - loss: 0.1607
# 11022/11022 [==============================] - 8s 767us/step - loss: 0.1701
#
# -----diveristy 0.2
# ----- Seedを生成しました: "気工夫の童《わらす》あ、山男に手足いしばらえてたふだ。」といつかだれかの話した言"
#
#
#
#
#
#
#
#
#
# 「おい、どれな顔どながら、みんなはだんだい。」と言いながら白いそっちを見ないこうにどてこっちへ帰ってきました
#
# -----diveristy 0.5
# ----- Seedを生成しました: "気工夫の童《わらす》あ、山男に手足いしばらえてたふだ。」といつかだれかの話した言"
#
# 「それに、けれど　どうど　どどうど　どどうど　どどうど　どどう
# ど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうど　どどうどどうどんどん
#
# -----diveristy 1.0
# ----- Seedを生成しました: "気工夫の童《わらす》あ、山男に手足いしばらえてたふだ。」といつかだれかの話した言"
#
#
#
# 　みんなは押わ
# 「んで、なんだよ。
#
#
#
#
#
#
# 　先生かちみんなははじびのうしろのひら》目をらびみました。一郎のにいさんが待っていました。投ました。そのうで、こっていたんだい。いて、四年生の人のけであみ玄
#
# -----diveristy 1.2
# ----- Seedを生成しました: "気工夫の童《わらす》あ、山男に手足いしばらえてたふだ。」といつかだれかの話した言"
#
#
#
#
#
#
#
# 「三郎な顔のほうはラのむな運だって、ましたらなぶ木のだっとわがた二から歩いて口を高をゃんとはじめ紫いめあをきてもには日さ
#
# --------------------------------------------------
# 繰り返し回数:  53
# Epoch 1/1
#  1664/11022 [===>..........................] - ETA: 7s - loss: 0.1003
# 11022/11022 [==============================] - 9s 783us/step - loss: 0.1583
#
# -----diveristy 0.2
# ----- Seedを生成しました: "きょろきょろ三郎のほうはみていても、やはり忙しそうに棒かくしをしたり三郎のほうへ"
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「おおい、ありあ、雨三郎はこ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "きょろきょろ三郎のほうはみていても、やはり忙しそうに棒かくしをしたり三郎のほうへ"
#
#
#
#
# 「お早ぎ。あとあ
# 「それから、それからど
#
# -----diveristy 1.0
# ----- Seedを生成しました: "きょろきょろ三郎のほうはみていても、やはり忙しそうに棒かくしをしたり三郎のほうへ"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----diveristy 1.2
# ----- Seedを生成しました: "きょろきょろ三郎のほうはみていても、やはり忙しそうに棒かくしをしたり三郎のほうへ"
#
#
#
#
#
# 「そうら早ぐで。」と言いながらろがそうです。
# 　その大きようどろそこでもみんなは下をして来ました。そ
#
# --------------------------------------------------
# 繰り返し回数:  54
# Epoch 1/1
# 11022/11022 [==============================] - 9s 780us/step - loss: 0.1606
#
# -----diveristy 0.2
# ----- Seedを生成しました: "て馬の名札を押えました。そのうしろから三郎がまるで色のなくなったくちびるをきっと"
#
#
#
#
#
#
#
#
#
#
#
# 　すると三郎は顔をなって、その前をとい
# 「お
#
# -----diveristy 0.5
# ----- Seedを生成しました: "て馬の名札を押えました。そのうしろから三郎がまるで色のなくなったくちびるをきっと"
#
#
#
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "て馬の名札を押えました。そのうしろから三郎がまるで色のなくなったくちびるをきっと"
# て馬の名札を押えました。そのうしろから三郎がまるで色のなくなったくちびるをきっと入り、じゃく見えてのへいているのです。いるないが、もう
# 　そこはろうんないは一つにけれて馬のか、にり
#
# -----diveristy 1.2
# ----- Seedを生成しました: "て馬の名札を押えました。そのうしろから三郎がまるで色のなくなったくちびるをきっと"
#
#
#
#
#
#
#
#
#
#
# 　まえなそ陰
#
# --------------------------------------------------
# 繰り返し回数:  55
# Epoch 1/1
# 11022/11022 [==============================] - 9s 785us/step - loss: 0.1513
#
# -----diveristy 0.2
# ----- Seedを生成しました: "あさあ、こいづも食べろ。」
# 「おじいさん。馬置いでくるが。」と一郎のにいさんが"
# あさあ、こいづも食べろ。」
# 「ああ、いさん、う来ょうからんとからたいてもだ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "あさあ、こいづも食べろ。」
# 「おじいさん。馬置いでくるが。」と一郎のにいさんが"
# あさあ、こいづも食べろ。」
#
#
#
#
#
#
#
#
#
#
#
# 「は
#
# -----diveristy 1.0
# ----- Seedを生成しました: "あさあ、こいづも食べろ。」
# 「おじいさん。馬置いでくるが。」と一郎のにいさんが"
# あさあ、こいづも食べろ。」
#
#
#
#
# 「
# 　みんなはこんのしきの下で見てまたのです。すがすがやっちへもっていました。みんなたい
#
# -----diveristy 1.2
# ----- Seedを生成しました: "あさあ、こいづも食べろ。」
# 「おじいさん。馬置いでくるが。」と一郎のにいさんが"
# あさあ、こいづも食べろ。」
#
#
#
#
#
#
#
#
#
#
#
#
# 「おの耕れるよう
#
# --------------------------------------------------
# 繰り返し回数:  56
# Epoch 1/1
#  8064/11022 [====================>.........] - ETA: 2s - loss: 0.1285
# 11022/11022 [==============================] - 9s 785us/step - loss: 0.1440
#
# -----diveristy 0.2
# ----- Seedを生成しました: "となりました。
# 　先生が言いました。
# 「みなさん、長い夏のお休みはおもしろか"
# となりました。
# 　先生が言いました。
#
#
#
#
# 「そんだら、みんなはだんました。又三郎が風のだっち
#
#
# 「お早ぐ。ど
#
#
# 「お早う。ど
#
# 「お早ぐ。ど
#
#
#
#
# 「お早ぱ。おら嘉助のおいるで、なないてもうきききました。
#
# -----diveristy 0.5
# ----- Seedを生成しました: "となりました。
# 　先生が言いました。
# 「みなさん、長い夏のお休みはおもしろか"
# となりました。
# 　先生が言いました。
# 「みなさん、長い夏のお休みはおもしろから何かすみんなの年生の人の人したくつ笑い
# 「そんなら、あとこっちへ戻ってとおりしばらくうかわった
#
# -----diveristy 1.0
# ----- Seedを生成しました: "となりました。
# 　先生が言いました。
# 「みなさん、長い夏のお休みはおもしろか"
# となりました。
# 　先生が言いました。
#
#
#
#
#
#
# 　耕助は顔いっと思いました。それ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "となりました。
# 　先生が言いました。
# 「みなさん、長い夏のお休みはおもしろか"
# となりました。
# 　先生が言いました。
#
# 　みん
# 「それから粘ごかなどどどうどんら一つっているのか、また一人につ立ってしました。そしての中を来るぞ。それからは一つじゃ生け帳
#
# --------------------------------------------------
# 繰り返し回数:  57
# Epoch 1/1
# 11022/11022 [==============================] - 9s 789us/step - loss: 0.1460
#
# -----diveristy 0.2
# ----- Seedを生成しました: "いようなので一郎も全く困ってしまいました。
# 「あいづは外国人だな。」
# 「学校"
# いようなので一郎も全く困ってしまいました。
# 「あいづは外国人だな。」
#
#
#
#
#
#
#
#
# 　けれどもやっと先
# 　それはたっとそのへのぼくとりました。それから
#
# -----diveristy 0.5
# ----- Seedを生成しました: "いようなので一郎も全く困ってしまいました。
# 「あいづは外国人だな。」
# 「学校"
# いようなので一郎も全く困ってしまいました。
# 「あいづは外国人だな。」
#
#
#
#
#
#
#
#
#
#
# 「では宿してもまっくじめさいがしました。けれどもましたのだようち三郎のほうはちょっと三郎のほうでばたほ》へついていたりして、
#
# -----diveristy 1.0
# ----- Seedを生成しました: "いようなので一郎も全く困ってしまいました。
# 「あいづは外国人だな。」
# 「学校"
# いようなので一郎も全く困ってしまいました。
# 「あいづは外国人だな。」
#
#
# 　ところが馬のもうはいつもどもらいまおうしょにするのよ
# 　ところが先生は別のまへ行っま
#
# -----diveristy 1.2
# ----- Seedを生成しました: "いようなので一郎も全く困ってしまいました。
# 「あいづは外国人だな。」
# 「学校"
# いようなので一郎も全く困ってしまいました。
# 「あいづは外国人だな。」
#
#
#
#
#
# 「であいい、先生はひらさながら嘉助がびました。何りは、嘉助のかちゃんと一本おこのに権んと一にの立ってゃますましたのでしたのでみんなもつるれらほ渡へ変ろして、またがやました。三郎もうでもなく
#
# --------------------------------------------------
# 繰り返し回数:  58
# Epoch 1/1
#  4352/11022 [==========>...................] - ETA: 5s - loss: 0.1134
# 11022/11022 [==============================] - 9s 793us/step - loss: 0.1454
#
# -----diveristy 0.2
# ----- Seedを生成しました: "てから、
# 「嘉助、二人して水掃ぐべな。」と言ってしゅろ箒《ぼうき》をもって来て"
# てから、
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「ああ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "てから、
# 「嘉助、二人して水掃ぐべな。」と言ってしゅろ箒《ぼうき》をもって来て"
# てから、
#
#
#
#
# 　それから
# -----diveristy 1.0
# ----- Seedを生成しました: "てから、
# 「嘉助、二人して水掃ぐべな。」と言ってしゅろ箒《ぼうき》をもって来て"
# てから、
#
#
#
#
#
#
#
#
#
#
#
# 　みんなは一んのにわかに、いって行あとおねむっていました。けれどもの関もほうです。草の変に、ご
#
# -----diveristy 1.2
# ----- Seedを生成しました: "てから、
# 「嘉助、二人して水掃ぐべな。」と言ってしゅろ箒《ぼうき》をもって来て"
# てから、
#
#
#
#
# 「
# 　三郎はひっとみんなのをちって、嘉助もおとして匹をばて来て窓とってきって来たが、今度をそれて来
#
# --------------------------------------------------
# 繰り返し回数:  59
# Epoch 1/1
# 11022/11022 [==============================] - 8s 767us/step - loss: 0.1343
#
# -----diveristy 0.2
# ----- Seedを生成しました: "何べんも鬼っこ［＃「鬼っこ」に傍点］をしました。
# 　しまいにとうとう三郎一人が"
# 何べんも鬼っこ［＃「鬼っこ」に傍点］をしました。
#
#
#
#
#
#
#
# 「又三郎びってるのでだって、あはきのうち
# 　三郎は、じゃみ行くなおこしました。
#
# -----diveristy 0.5
# ----- Seedを生成しました: "何べんも鬼っこ［＃「鬼っこ」に傍点］をしました。
# 　しまいにとうとう三郎一人が"
# 何べんも鬼っこ［＃「鬼っこ」に傍点］をしました。
#
#
#
#
#
#
#
#
#
#
#
#
#
# 「石んないでった。えるとさっかりました。嘉助はおと言いながら
#
# -----diveristy 1.0
# ----- Seedを生成しました: "何べんも鬼っこ［＃「鬼っこ」に傍点］をしました。
# 　しまいにとうとう三郎一人が"
# 何べんも鬼っこ［＃「鬼っこ」に傍点］をしました。
#
#
# 「
# 　みんなはちんとと下のとをぐるとびすと、馬は無風がど生の谷じもないてい
#
# -----diveristy 1.2
# ----- Seedを生成しました: "何べんも鬼っこ［＃「鬼っこ」に傍点］をしました。
# 　しまいにとうとう三郎一人が"
# 何べんも鬼っこ［＃「鬼っこ」に傍点］をしました。
#
#
#
#
#
#
#
#
#
#
#
#
# 「石べ渡さす。おら少しからぢゃ
