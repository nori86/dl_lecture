# %%
# !wget https://github.com/rekiksab/Yelp-Data-Challenge-2013/raw/master/yelp_challenge/yelp_phoenix_academic_dataset/yelp_academic_dataset_review.json
# Out:
# --2019-09-08 12:25:30--  https://github.com/rekiksab/Yelp-Data-Challenge-2013/raw/master/yelp_challenge/yelp_phoenix_academic_dataset/yelp_academic_dataset_review.json
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/rekiksab/Yelp-Data-Challenge-2013/master/yelp_challenge/yelp_phoenix_academic_dataset/yelp_academic_dataset_review.json [following]
# --2019-09-08 12:25:31--  https://raw.githubusercontent.com/rekiksab/Yelp-Data-Challenge-2013/master/yelp_challenge/yelp_phoenix_academic_dataset/yelp_academic_dataset_review.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 216292386 (206M) [text/plain]
# Saving to: ‘yelp_academic_dataset_review.json’
#
# yelp_academic_datas 100%[===================>] 206.27M   168MB/s    in 1.2s
#
# 2019-09-08 12:25:34 (168 MB/s) - ‘yelp_academic_dataset_review.json’ saved [216292386/216292386]

# %%
import pandas as pd
import json
from sklearn.feature_extraction.text import CountVectorizer

# %%
# 最初の10,000 件のレビューを読み込む
with open('yelp_academic_dataset_review.json') as f:
  js = []
  for i in range(10000):
    js.append(json.loads(f.readline()))
    review_df = pd.DataFrame(js)
