# %%
# !pip install git-lfs

# %%
# !apt-get install git-lfs
# !git lfs install
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   git-lfs
# 0 upgraded, 1 newly installed, 0 to remove and 8 not upgraded.
# Need to get 2,129 kB of archives.
# After this operation, 7,662 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 git-lfs amd64 2.3.4-1 [2,129 kB]
# Fetched 2,129 kB in 2s (1,292 kB/s)
# Selecting previously unselected package git-lfs.
# (Reading database ... 130912 files and directories currently installed.)
# Preparing to unpack .../git-lfs_2.3.4-1_amd64.deb ...
# Unpacking git-lfs (2.3.4-1) ...
# Setting up git-lfs (2.3.4-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Updated git hooks.
# Git LFS initialized.

# %%
# !git clone https://github.com/YBIGTA/pytorch-hair-segmentation.git
# Out:
# Cloning into 'pytorch-hair-segmentation'...
# remote: Enumerating objects: 400, done.
# remote: Total 400 (delta 0), reused 0 (delta 0), pack-reused 400
# Receiving objects: 100% (400/400), 45.83 MiB | 10.03 MiB/s, done.
# Resolving deltas: 100% (215/215), done.
# Filtering content: 100% (7/7), 147.79 MiB | 15.85 MiB/s, done.

# %%
# %cd pytorch-hair-segmentation/
# Out:
# /content/pytorch-hair-segmentation

# %%
# !pip install pytorch-ignite

# %%
# specify a directory for dataset to be downloaded into, else default is ./data/
# !sh data/figaro.sh
# Out:
# navigating to ./data/ ...
# Now downloading Figaro1k.zip ...
# --2019-06-19 02:54:08--  https://www.dropbox.com/s/35momrh68zuhkei/Figaro1k.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.1, 2620:100:6030:1::a27d:5001
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/35momrh68zuhkei/Figaro1k.zip [following]
# --2019-06-19 02:54:08--  https://www.dropbox.com/s/raw/35momrh68zuhkei/Figaro1k.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc5fe0740519c24503738a6895d8.dl.dropboxusercontent.com/cd/0/inline/AjFUGrd20JqITUm-70SAlCihjeZRCtbVjJsCJba4x_-5aRIHHd_ahbplN8Tz1xaerwG9BKcVoCDHV1m7cvK0LjD_5xD_GYzZ6bTIIvp8_4H0fA/file# [following]
# ...

# %%
# !python3 evaluate.py \
  --networks pspnet_resnet101 \
  --ckpt_dir ./models/pspnet_resnet101_sgd_lr_0.002_epoch_100_test_iou_0.918.pth \
  --dataset figaro \
  --data_dir ./data/Figaro1k \
  --save_dir ./ \
  --use_gpu True
# Out:
# [  1/210] processing image...
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2457: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2539: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# [  2/210] processing image...
# [  3/210] processing image...
# [  4/210] processing image...
# [  5/210] processing image...
# [  6/210] processing image...
# [  7/210] processing image...
# [  8/210] processing image...
# [  9/210] processing image...
# [ 10/210] processing image...
# [ 11/210] processing image...
# ...

# %%
# !pwd
# Out:
# /content/pytorch-hair-segmentation

# %%
# %mkdir -p input/Original/Testing
# %mkdir -p input/GT/Testing

# %%
# !python3 pytorch-hair-segmentaion.py \
  --networks pspnet_resnet101 \
  --ckpt_dir ./models/pspnet_resnet101_sgd_lr_0.002_epoch_100_test_iou_0.918.pth \
  --dataset figaro \
  --data_dir ./input \
  --save_dir ./ \
  --use_gpu True
# Out:
# [  1/  5] processing image...
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2457: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2539: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# masktop:14
# maskbottom:434
# maskleft:14
# maskright:434
# [  2/  5] processing image...
# masktop:14
# maskbottom:273
# maskleft:15
# maskright:209
# [  3/  5] processing image...
# masktop:11
# maskbottom:693
# maskleft:0
# maskright:1024
# [  4/  5] processing image...
# masktop:2
# maskbottom:382
# maskleft:4
# maskright:604
# ...

# %%
# !ls -la ./input/Original/Testing/
# Out:
# total 44
# drwxr-xr-x 3 root root  4096 Jun 19 05:02 .
# drwxr-xr-x 3 root root  4096 Jun 19 03:24 ..
# drwxr-xr-x 2 root root  4096 Jun 19 04:59 .ipynb_checkpoints
# -rw-r--r-- 1 root root 29719 Jun 19 04:59 women_001.jpg

# %%
# !rm -rf ./input/Original/Testing/.ipynb_checkpoints
# !rm -rf ./input/GT/Testing/.ipynb_checkpoints
