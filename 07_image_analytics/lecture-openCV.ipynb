# %%
import cv2

# %%
# 画像のダウンロード
import urllib.request as req
url = "http://uta.pw/shodou/img/28/214.png"
req.urlretrieve(url, "test.png")

# OpenCVで読み込む
import cv2
img = cv2.imread("test.png")
print(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
# データをアップロードする
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-074d80f2-10ed-49c9-8c9b-b3e625638bf1" name="files[]" multiple disabled />
#      <output id="result-074d80f2-10ed-49c9-8c9b-b3e625638bf1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.jpg to test (1).jpg

# %%
import cv2

# %%
# 画像をインライン表示する
import matplotlib.pyplot as plt
# %matplotlib inline

# ダウンロードした画像を画面に表示させる
img = cv2.imread("test.jpg")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# ダウンロードした画像を画面に表示させる
# 軸の表示をOFFにする
img = cv2.imread("test.jpg")
plt.axis("off")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# 画像を保存する
cv2.imwrite("out-test.jpg", img)
# Out:
# True

# %%
# 画像のリサイズ
img = cv2.imread("test.jpg")
im2 = cv2.resize(img, (800, 300))

# 画像を表示
plt.imshow(cv2.cvtColor(im2, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# 画像の切り取り
img = cv2.imread("test.jpg")
im2 = img[25:175, 40:190]

# 画像を表示
plt.imshow(cv2.cvtColor(im2, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# 画像をリサイズ
im2 = cv2.resize(im2, (400, 400))

# 画像を表示
plt.imshow(cv2.cvtColor(im2, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# データをアップロードする
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-91c9502d-c782-4578-a61d-c6e823c5a998" name="files[]" multiple disabled />
#      <output id="result-91c9502d-c782-4578-a61d-c6e823c5a998">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving face-test.jpg to face-test (1).jpg

# %%
# データをアップロードする
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9d51b1b2-f583-4e71-9698-058bf2e41138" name="files[]" multiple disabled />
#      <output id="result-9d51b1b2-f583-4e71-9698-058bf2e41138">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving haarcascade_frontalface_alt.xml to haarcascade_frontalface_alt.xml

# %%
# 顔検出
# カスケードファイルを指定して検出器を作成
cascade_file = "haarcascade_frontalface_alt.xml"
cascade = cv2.CascadeClassifier(cascade_file)

# %%
# 画像の読み込んでグレイスケールに変換する
img = cv2.imread("face-test.jpg")
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
# 顔認識を実行
face_list = cascade.detectMultiScale(img_gray, minSize=(150,150))
# 結果を確認
if len(face_list) == 0:
    print("失敗")
    quit()
# 認識した部分に印をつける
for (x,y,w,h) in face_list:
    print("顔の座標=", x, y, w, h)
    red = (0, 0, 255)
    cv2.rectangle(img, (x, y), (x+w, y+h), red, thickness=20)
# Out:
# 顔の座標= 343 85 178 178

# %%
#画像を出力
cv2.imwrite("face-detect.png", img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# 顔にモザイクをかける

# %%
# 動画の表示・出力

# %%
import cv2
import sys

# %%
cap = cv2.VideoCapture("movie/Cosmos.mp4")
if cap.isOpened() = False:
  sys.exit()
ret, frame = cap.read()
h, w = frame.shape[:2]
fourcc = cv2.VideoWriter_fourcc(*"XVID")
dst = cv2.VideoWriter("output/test/avi", fourcc, 30.0, (w, h))

while True:
  ret, frame = cap.read()
  if ret = False:
    break
  cv2.imshow("img", frame)
  dst.write(frame)
  if cv2.waiteKey(30) == 27: # 27はESCキー
    break
cv2.destoryAllWindow()
