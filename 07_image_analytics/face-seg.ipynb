# %%
# !git clone https://github.com/kampta/face-seg.git
# Out:
# Cloning into 'face-seg'...
# remote: Enumerating objects: 16, done.
# remote: Total 16 (delta 0), reused 0 (delta 0), pack-reused 16
# Unpacking objects: 100% (16/16), done.

# %%
# %cd face-seg/
# Out:
# /content/face-seg

# %%
# !mkdir data

# %%
# !python test.py --data-folder data/ --pre-trained checkpoints/model.pt
# Out:
# Model loaded
# 3  files in folder  data/
# <Figure size 640x480 with 6 Axes>
