# %%
from sklearn.cluster import KMeans
import numpy as np

# %%
X = np.array([[1, 2], [1, 4], [1, 0],
              [4, 2], [4, 4], [4, 0]])

# %%
kmeans = KMeans(n_clusters=2, random_state=0).fit(X)

# %%
# クラスタリング後の結果の表示
kmeans.labels_
# Out:
# array([0, 0, 0, 1, 1, 1], dtype=int32)

# %%
# テストデータによる予測
kmeans.predict([[0, 0], [4, 4]])
# Out:
# array([0, 1], dtype=int32)

# %%
# クラスターの重心の表示
kmeans.cluster_centers_
# Out:
# array([[1., 2.],
#        [4., 2.]])

# %%
# DBSCAN

# %%
from sklearn.cluster import DBSCAN
import numpy as np

# %%
X = np.array([[1, 2], [1, 4], [1, 0],
              [4, 2], [4, 4], [4, 0]])

# %%
dbscan = DBSCAN(eps=3, min_samples=2).fit(X)

# %%
# クラスタリング後の結果の表示
dbscan.labels_
# Out:
# array([0, 0, 0, 0, 0, 0])

# %%
dbscan.fit_predict([[0, 0], [4, 4]])
# Out:
# array([-1, -1])

# %%
dbscan.get_params
# Out:
# <bound method BaseEstimator.get_params of DBSCAN(algorithm='auto', eps=3, leaf_size=30, metric='euclidean',
#     metric_params=None, min_samples=2, n_jobs=None, p=None)>

# %%
dbscan = DBSCAN(eps=2, min_samples=1).fit(X)

# %%
# クラスタリング後の結果の表示
dbscan.labels_
# Out:
# array([0, 0, 0, 1, 1, 1])

# %%
dbscan.fit_predict([[0, 0], [4, 4]])
# Out:
# array([0, 1])
