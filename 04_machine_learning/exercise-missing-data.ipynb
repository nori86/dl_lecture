# %%
# データの準備
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.rand(10, 4))

# %%
df.iloc[1, 0]   = np.nan
df.iloc[2:3, 2] = np.nan
df.iloc[5:, 3]  = np.nan

# %%
df

# %%
df.isnull()

# %%
# データフレームの欠損データをまとめるテーブルの関数
def missing_values_table(df): 
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum()/len(df)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        return mis_val_table_ren_columns 

# dataに欠損があるかどうか確認
missing_values_table(df)

# %%
df1 = df.copy()
df1

# %%
# リストワイズ削除
df1.dropna()

# %%
df2 = df.copy()
df2

# %%
# ペアワイズ削除
df2[[0, 1]].dropna()

# %%
df3 = df.copy()
df3

# %%
# 指定の値で埋める
df3.fillna(0)

# %%
df4 = df.copy()
df4

# %%
df4.fillna(method = 'ffill')

# %%
df5 = df.copy()
df5

# %%
df5.mean()

# %%
# 平均値で埋める
df5.fillna(df.mean())

# %% [markdown]
# ### 演習

# %%
# データの準備
import numpy as np
import pandas as pd

df = pd.DataFrame(np.random.rand(10, 4))

df.iloc[2:3, 0]   = np.nan
df.iloc[5:8, 2] = np.nan
df.iloc[1, 3]  = np.nan

df

# %% [markdown]
# ##Q１．0列、2列目に関してNaNを含む行を削除してください。（ペアワイズ削除）

# %% [markdown]
# ## Q２．各列の後ろの値を用いて欠損データの穴埋めを行って下さい。

# %% [markdown]
# ## Q３．各列の最小値を用いて欠損データの穴埋めを行って下さい。
