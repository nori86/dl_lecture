# %%
# gitからclone
# !git clone https://github.com/ildoonet/tf-pose-estimation.git

# %%
# 必要なライブラリをインストール
# %cd ./tf-pose-estimation
# !ls
# !pip install -r requirements.txt

# %%
# !apt-get -q -y install swig

# %%
# %cd tf_pose/pafprocess
# !swig -python -c++ pafprocess.i && python3 setup.py build_ext --inplace

# %%
# %cd /content/tf-openpose
# !python setup.py install

# %%
# %cd /content/tf-pose-estimation/models/graph/cmu
# !bash download.sh

# %%
# 画像を取得
# %cd /content/tf-pose-estimation/images
# !wget http://super-watashi.com/wp-content/uploads/2015/01/%E3%82%B8%E3%83%A7%E3%82%B3%E3%83%93%E3%83%83%E3%83%8131.jpg

# %%
# 移動
# %cd /content/tf-pose-estimation/

# %%
# 実行
# %run -i run.py --model=mobilenet_thin --resize=432x368 \
--image=/content/tf-pose-estimation/images/ジョコビッチ31.jpg
