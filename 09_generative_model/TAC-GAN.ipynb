# %%
# !git clone https://github.com/dashayushman/TAC-GAN.git
# Out:
# Cloning into 'TAC-GAN'...
# remote: Counting objects: 272, done.
# remote: Total 272 (delta 0), reused 0 (delta 0), pack-reused 272
# Receiving objects: 100% (272/272), 101.21 KiB | 4.60 MiB/s, done.
# Resolving deltas: 100% (158/158), done.

# %%
# !pip install theano
# Out:
# ...
#     100% |████████████████████████████████| 2.8MB 5.1MB/s
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/87/1e/28/4a63195927452fb42d4ea6d1e5b3b1690409d66802cc9e1e6e
# Successfully built theano
# ...

# %%
cd TAC-GAN
# Out:
# /content/TAC-GAN

# %%
# !python dataprep.py --data_dir=Data --dataset=flowers
# Out:
# Traceback (most recent call last):
#   File "dataprep.py", line 145, in <module>
#     main()
#   File "dataprep.py", line 139, in main
#     save_caption_vectors_flowers(dataset_dir)
#   File "dataprep.py", line 60, in save_caption_vectors_flowers
#     image_files = [f for f in os.listdir(img_dir) if 'jpg' in f]
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/datasets/flowers/jpg'

# %%
# !ls
# Out:
# create_dataset.py  encode_text.py      msssim.py	 t_interpolation.py
# Data		   generate_images.py  __pycache__	 train.py
# dataprep.py	   inception_score.py  README.md	 Utils
# decoder.py	   LICENSE	       requirements.txt  z_interpolation.py
# encoder.py	   model.py	       skipthoughts.py
